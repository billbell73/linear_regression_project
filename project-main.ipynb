# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import PowerTransformer

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
numerics_df = pd.read_pickle("./porsches_df.pkl")
numerics_df.describe()
# Out:
#              mileage          price  engine_size   doors      0-6Xmph  \
# count    1560.000000    1560.000000  1560.000000  1560.0  1560.000000
# mean    39252.214103   79019.195513     3.521154     2.0     4.308462
# std     32558.468638   52847.684672     0.344090     0.0     0.733313
# min        10.000000    8950.000000     3.000000     2.0     2.700000
# 25%     12637.500000   37898.750000     3.000000     2.0     3.700000
# 50%     30971.500000   73990.000000     3.600000     2.0     4.300000
# 75%     60019.250000  104000.000000     3.800000     2.0     4.800000
# max    286000.000000  495990.000000     4.000000     2.0     5.900000
#
#          top_speed  cylinders        power  convertible       manual  \
# count  1560.000000     1560.0  1560.000000  1560.000000  1560.000000
# mean    185.842949        6.0   409.132692     0.330128     0.270513
# std       8.820152        0.0    77.685388     0.470410     0.444367
# min     118.000000        6.0   250.000000     0.000000     0.000000
# 25%     179.000000        6.0   350.000000     0.000000     0.000000
# 50%     187.000000        6.0   400.000000     0.000000     0.000000
# 75%     191.000000        6.0   444.000000     1.000000     1.000000
# max     211.000000        6.0   690.000000     1.000000     1.000000
#
#          years_old
# count  1560.000000
# mean      9.392308
# std       6.693027
# min       0.000000
# 25%       4.000000
# 50%       8.000000
# 75%      15.000000
# max      32.000000

# %%
numerics_df = numerics_df.drop(columns=["doors", "cylinders"])

# %%
numerics_df.describe()
# Out:
#              mileage          price  engine_size      0-6Xmph    top_speed  \
# count    1560.000000    1560.000000  1560.000000  1560.000000  1560.000000
# mean    39252.214103   79019.195513     3.521154     4.308462   185.842949
# std     32558.468638   52847.684672     0.344090     0.733313     8.820152
# min        10.000000    8950.000000     3.000000     2.700000   118.000000
# 25%     12637.500000   37898.750000     3.000000     3.700000   179.000000
# 50%     30971.500000   73990.000000     3.600000     4.300000   187.000000
# 75%     60019.250000  104000.000000     3.800000     4.800000   191.000000
# max    286000.000000  495990.000000     4.000000     5.900000   211.000000
#
#              power  convertible       manual    years_old
# count  1560.000000  1560.000000  1560.000000  1560.000000
# mean    409.132692     0.330128     0.270513     9.392308
# std      77.685388     0.470410     0.444367     6.693027
# min     250.000000     0.000000     0.000000     0.000000
# 25%     350.000000     0.000000     0.000000     4.000000
# 50%     400.000000     0.000000     0.000000     8.000000
# 75%     444.000000     1.000000     1.000000    15.000000
# max     690.000000     1.000000     1.000000    32.000000

# %%
sns.pairplot(numerics_df)

# %%
def vifs(df):
    vif = pd.DataFrame()
    vif['variables'] = df.columns
    vif['vif'] =[variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    print(vif)

# %%
def simple_lr(y, X):
    model = sm.OLS(y, sm.add_constant(X))
    results = model.fit()
    print(results.summary())
    return results

# %%
def plot_residuals(results):
    fig, (ax0, ax1, ax2) = plt.subplots(1, 3)
    fig.set_size_inches(26, 9)

    ax0.scatter(results.predict(), results.resid)
    ax0.set_ylabel('Residual')
    ax0.set_xlabel('Predicted price')
    ax0.set_title('Predicted target against residual')

    sns.distplot(results.resid, ax=ax1)
    sns.despine()
    ax1.set_xlabel('Residuals')
    ax1.set_title('Distribution of Residuals')

    stats.probplot(results.resid, dist="norm", plot=ax2)
    ax2.set_title("Normal Q-Q plot")
    ax2.set_xlabel("Theoretical Quantiles")
    ax2.set_ylabel("Ordered Values")

    fig.suptitle("Plotting residuals", size=16)

# %%
def cv_lr(y, X):
    kf = KFold(n_splits=5, shuffle=True)

    r2s, rmses, maes = [], [], []
    for train_ind, val_ind in kf.split(X,y):
        X_train, y_train = X.iloc[train_ind], y.iloc[train_ind]
        X_val, y_val = X.iloc[val_ind], y.iloc[val_ind]
        lm = LinearRegression()
        lm.fit(X_train, y_train)
        r2s.append(lm.score(X_val, y_val))
        rmses.append(mean_squared_error(y_val, lm.predict(X_val), squared=False))
        maes.append(mean_absolute_error(y_val, lm.predict(X_val)))

    print(f'\n\nMean cv r^2: {np.mean(r2s):.3f} +- {np.std(r2s):.3f}')
    print(f'Mean cv RMSE: {np.mean(rmses):.3f} +- {np.std(rmses):.3f}')
    print(f'Mean cv MAE: {np.mean(maes):.3f} +- {np.std(maes):.3f}')

# %%
def evaluate(y, X):
    vifs(X)
    results = simple_lr(y, X)
    plot_residuals(results)
    cv_lr(y, X)

# %%
X = numerics_df.drop("price", axis=1)
y = numerics_df.loc[:, "price"]
y.head()
# Out:
# 202109207563077    116900.0
# 202109227674550     15995.0
# 202108136210396     15995.0
# 202106043455421     15995.0
# 202105082360787     15995.0
# Name: price, dtype: float64

# %%
X_non_test, X_test, y_non_test, y_test = train_test_split(X, y, test_size=.2)

# %%
evaluate(y_non_test, X_non_test)
# Out:
#      variables         vif
# 0      mileage    6.254027
# 1  engine_size  194.318502
# 2      0-6Xmph  240.671964
# 3    top_speed  796.037000
# 4        power  354.885254
# 5  convertible    1.627322
# 6       manual    1.756545
# 7    years_old   12.344148
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     318.5
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          3.19e-294
# Time:                        15:44:52   Log-Likelihood:                -14632.
# No. Observations:                1248   AIC:                         2.928e+04
# Df Residuals:                    1239   BIC:                         2.933e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        9.603e+04   4.91e+04      1.955      0.051    -316.808    1.92e+05
# mileage        -0.5408      0.042    -12.827      0.000      -0.623      -0.458
# engine_size -1586.2262   3367.657     -0.471      0.638   -8193.168    5020.715
# 0-6Xmph       1.86e+04   4061.352      4.579      0.000    1.06e+04    2.66e+04
# top_speed   -1666.7184    246.078     -6.773      0.000   -2149.495   -1183.942
# power         620.5324     38.464     16.133      0.000     545.070     695.995
# convertible -3742.4403   1894.881     -1.975      0.048   -7459.970     -24.911
# manual       1.652e+04   2157.339      7.656      0.000    1.23e+04    2.07e+04
# years_old   -1892.6254    259.940     -7.281      0.000   -2402.597   -1382.653
# ==============================================================================
# Omnibus:                      972.082   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29730.130
# Skew:                           3.330   Prob(JB):                         0.00
# Kurtosis:                      25.965   Cond. No.                     2.94e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.672 +- 0.080
# Mean cv RMSE: 29778.034 +- 5904.448
# Mean cv MAE: 17675.886 +- 2045.181

# %%
X_non_test_2 = X_non_test.drop(columns=['top_speed', 'engine_size'])

evaluate(y_non_test, X_non_test_2)
# Out:
#      variables        vif
# 0      mileage   6.181054
# 1      0-6Xmph  29.492420
# 2        power  13.837627
# 3  convertible   1.536624
# 4       manual   1.729271
# 5    years_old  10.304689
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     402.3
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          7.19e-287
# Time:                        15:44:53   Log-Likelihood:                -14655.
# No. Observations:                1248   AIC:                         2.932e+04
# Df Residuals:                    1241   BIC:                         2.936e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.845e+05    2.6e+04     -7.095      0.000   -2.35e+05   -1.33e+05
# mileage        -0.5784      0.042    -13.640      0.000      -0.662      -0.495
# 0-6Xmph      2.354e+04   3736.931      6.298      0.000    1.62e+04    3.09e+04
# power         484.6846     29.099     16.657      0.000     427.596     541.773
# convertible -3237.1949   1901.805     -1.702      0.089   -6968.303     493.913
# manual       1.348e+04   2147.264      6.277      0.000    9266.708    1.77e+04
# years_old   -1716.3346    252.728     -6.791      0.000   -2212.155   -1220.514
# ==============================================================================
# Omnibus:                      986.288   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28283.008
# Skew:                           3.434   Prob(JB):                         0.00
# Kurtosis:                      25.287   Cond. No.                     1.54e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.651 +- 0.057
# Mean cv RMSE: 30509.357 +- 5639.475
# Mean cv MAE: 18738.250 +- 2049.393

# %%
X_non_test_3 = X_non_test_2.drop(columns=['0-6Xmph', 'years_old'])

evaluate(y_non_test, X_non_test_3)
# Out:
#      variables       vif
# 0      mileage  2.194234
# 1        power  2.302240
# 2  convertible  1.467480
# 3       manual  1.484220
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     561.8
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          8.66e-277
# Time:                        15:44:54   Log-Likelihood:                -14685.
# No. Observations:                1248   AIC:                         2.938e+04
# Df Residuals:                    1243   BIC:                         2.941e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.187e+04   6964.615     -6.012      0.000   -5.55e+04   -2.82e+04
# mileage        -0.6652      0.034    -19.720      0.000      -0.731      -0.599
# power         352.6685     14.491     24.337      0.000     324.239     381.098
# convertible  -641.4565   1888.223     -0.340      0.734   -4345.912    3062.999
# manual       1.083e+04   2087.320      5.188      0.000    6734.137    1.49e+04
# ==============================================================================
# Omnibus:                      971.503   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27325.942
# Skew:                           3.362   Prob(JB):                         0.00
# Kurtosis:                      24.916   Cond. No.                     4.01e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.640 +- 0.035
# Mean cv RMSE: 31253.804 +- 1903.004
# Mean cv MAE: 19075.412 +- 862.787

# %%
X_non_test_4 = X_non_test_2.drop(columns=['0-6Xmph', 'mileage'])
X_non_test_4['mileage per year'] = X_non_test['mileage'] / (X_non_test['years_old'] + 1)

evaluate(y_non_test, X_non_test_4)
# Out:
#           variables       vif
# 0             power  3.959896
# 1       convertible  1.480303
# 2            manual  1.731119
# 3         years_old  3.424844
# 4  mileage per year  4.090945
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     504.2
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          6.96e-296
# Time:                        15:44:55   Log-Likelihood:                -14638.
# No. Observations:                1248   AIC:                         2.929e+04
# Df Residuals:                    1242   BIC:                         2.932e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1389.2801   7848.526      0.177      0.860    -1.4e+04    1.68e+04
# power              310.1411     15.059     20.596      0.000     280.598     339.684
# convertible       -510.1169   1819.260     -0.280      0.779   -4079.280    3059.046
# manual             1.18e+04   2126.902      5.550      0.000    7630.736     1.6e+04
# years_old        -2797.6761    177.377    -15.772      0.000   -3145.668   -2449.685
# mileage per year    -7.3015      0.462    -15.801      0.000      -8.208      -6.395
# ==============================================================================
# Omnibus:                     1053.190   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37595.993
# Skew:                           3.715   Prob(JB):                         0.00
# Kurtosis:                      28.842   Cond. No.                     3.75e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.75e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.664 +- 0.040
# Mean cv RMSE: 30125.874 +- 3957.315
# Mean cv MAE: 18282.945 +- 911.206

# %%
X_non_test_5 = X_non_test_4.drop('convertible', axis=1)

evaluate(y_non_test, X_non_test_5)
# Out:
#           variables       vif
# 0             power  3.657322
# 1            manual  1.724586
# 2         years_old  3.379422
# 3  mileage per year  4.090699
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     630.7
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          2.71e-297
# Time:                        15:44:56   Log-Likelihood:                -14638.
# No. Observations:                1248   AIC:                         2.929e+04
# Df Residuals:                    1243   BIC:                         2.931e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1109.1274   7781.785      0.143      0.887   -1.42e+04    1.64e+04
# power              310.3453     15.035     20.641      0.000     280.848     339.843
# manual            1.185e+04   2120.467      5.587      0.000    7686.799     1.6e+04
# years_old        -2798.0682    177.306    -15.781      0.000   -3145.920   -2450.217
# mileage per year    -7.2960      0.462    -15.809      0.000      -8.201      -6.391
# ==============================================================================
# Omnibus:                     1053.338   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37639.192
# Skew:                           3.715   Prob(JB):                         0.00
# Kurtosis:                      28.858   Cond. No.                     3.72e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.72e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.666 +- 0.057
# Mean cv RMSE: 30058.316 +- 3314.326
# Mean cv MAE: 18195.848 +- 831.019

# %%
X_non_test_6 = X_non_test_5.copy()
X_non_test_6['max_mph_per_bhp'] = X_non_test['top_speed'] / X_non_test['power']

evaluate(y_non_test, X_non_test_6)
# Out:
#           variables        vif
# 0             power  14.479866
# 1            manual   1.741381
# 2         years_old   6.209469
# 3  mileage per year   4.768902
# 4   max_mph_per_bhp  30.875319
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.676
# Method:                 Least Squares   F-statistic:                     521.8
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):          4.29e-302
# Time:                        15:44:57   Log-Likelihood:                -14623.
# No. Observations:                1248   AIC:                         2.926e+04
# Df Residuals:                    1242   BIC:                         2.929e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -2.409e+05   4.56e+04     -5.288      0.000    -3.3e+05   -1.52e+05
# power              549.3156     46.768     11.746      0.000     457.563     641.069
# manual            1.103e+04   2102.402      5.247      0.000    6906.254    1.52e+04
# years_old        -3212.0326    191.426    -16.780      0.000   -3587.586   -2836.479
# mileage per year    -7.1683      0.457    -15.685      0.000      -8.065      -6.272
# max_mph_per_bhp   3.173e+05   5.89e+04      5.389      0.000    2.02e+05    4.33e+05
# ==============================================================================
# Omnibus:                     1115.477   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            48390.648
# Skew:                           3.993   Prob(JB):                         0.00
# Kurtosis:                      32.442   Cond. No.                     3.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.666 +- 0.052
# Mean cv RMSE: 29911.214 +- 4387.765
# Mean cv MAE: 17822.574 +- 644.034

# %%
log_y = np.log(y_non_test)

evaluate(log_y, X_non_test_6)
# Out:
#           variables        vif
# 0             power  14.479866
# 1            manual   1.741381
# 2         years_old   6.209469
# 3  mileage per year   4.768902
# 4   max_mph_per_bhp  30.875319
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     930.5
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:44:57   Log-Likelihood:                -272.19
# No. Observations:                1248   AIC:                             556.4
# Df Residuals:                    1242   BIC:                             587.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               11.6366      0.462     25.196      0.000      10.730      12.543
# power                0.0021      0.000      4.503      0.000       0.001       0.003
# manual               0.0615      0.021      2.885      0.004       0.020       0.103
# years_old           -0.0484      0.002    -24.967      0.000      -0.052      -0.045
# mileage per year  -8.18e-05   4.63e-06    -17.657      0.000   -9.09e-05   -7.27e-05
# max_mph_per_bhp     -1.5132      0.597     -2.535      0.011      -2.684      -0.342
# ==============================================================================
# Omnibus:                      676.281   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5616.223
# Skew:                           2.397   Prob(JB):                         0.00
# Kurtosis:                      12.220   Cond. No.                     3.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.784 +- 0.020
# Mean cv RMSE: 0.303 +- 0.021
# Mean cv MAE: 0.195 +- 0.011

# %%
poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_non_test_5)

poly_non_test_5_df = pd.DataFrame(X_train_poly, columns = poly.get_feature_names(X_non_test_5.columns), index=X_non_test_5.index)

# %%
poly_non_test_5_df.to_pickle("./poly_non_test_5_df.pkl")
y_non_test.to_pickle("./y_non_test.pkl")

poly_non_test_5_df.head()
# Out:
#                    1  power  manual  years_old  mileage per year   power^2  \
# 202106224112829  1.0  325.0     1.0       15.0       4921.375000  105625.0
# 202110148485474  1.0  350.0     1.0       15.0       1860.312500  122500.0
# 202108246593754  1.0  250.0     1.0       31.0       2545.093750   62500.0
# 202108236550132  1.0  365.0     1.0        3.0       4750.000000  133225.0
# 202110268901845  1.0  365.0     1.0        5.0       3666.666667  133225.0
#
#                  power manual  power years_old  power mileage per year  \
# 202106224112829         325.0           4875.0            1.599447e+06
# 202110148485474         350.0           5250.0            6.511094e+05
# 202108246593754         250.0           7750.0            6.362734e+05
# 202108236550132         365.0           1095.0            1.733750e+06
# 202110268901845         365.0           1825.0            1.338333e+06
#
#                  manual^2  manual years_old  manual mileage per year  \
# 202106224112829       1.0              15.0              4921.375000
# 202110148485474       1.0              15.0              1860.312500
# 202108246593754       1.0              31.0              2545.093750
# 202108236550132       1.0               3.0              4750.000000
# 202110268901845       1.0               5.0              3666.666667
#
#                  years_old^2  years_old mileage per year  mileage per year^2
# 202106224112829        225.0                73820.625000        2.421993e+07
# 202110148485474        225.0                27904.687500        3.460763e+06
# 202108246593754        961.0                78897.906250        6.477502e+06
# 202108236550132          9.0                14250.000000        2.256250e+07
# 202110268901845         25.0                18333.333333        1.344444e+07

# %%
evaluate(y_non_test, poly_non_test_5_df)
# Out:
#                      variables          vif
# 0                            1  4626.077664
# 1                        power   385.614106
# 2                       manual          inf
# 3                    years_old   302.945106
# 4             mileage per year    93.964184
# 5                      power^2   260.097477
# 6                 power manual    81.282001
# 7              power years_old   110.271361
# 8       power mileage per year    60.929210
# 9                     manual^2          inf
# 10            manual years_old    14.146099
# 11     manual mileage per year     7.500902
# 12                 years_old^2    33.370621
# 13  years_old mileage per year    14.609388
# 14          mileage per year^2     5.456252
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     425.0
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:44:58   Log-Likelihood:                -14268.
# No. Observations:                1248   AIC:                         2.856e+04
# Df Residuals:                    1234   BIC:                         2.864e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# 1                          -1.705e+04   4.32e+04     -0.394      0.694   -1.02e+05    6.78e+04
# power                        222.2475    163.394      1.360      0.174     -98.313     542.808
# manual                     -4.935e+04   8466.746     -5.829      0.000    -6.6e+04   -3.27e+04
# years_old                  -4290.1990   1658.539     -2.587      0.010   -7544.068   -1036.330
# mileage per year              23.7875      3.182      7.476      0.000      17.545      30.030
# power^2                        0.3411      0.153      2.223      0.026       0.040       0.642
# power manual                 294.8584     33.568      8.784      0.000     229.003     360.714
# power years_old               -8.1797      3.093     -2.645      0.008     -14.247      -2.112
# power mileage per year        -0.0673      0.006    -10.548      0.000      -0.080      -0.055
# manual^2                   -4.935e+04   8466.746     -5.829      0.000    -6.6e+04   -3.27e+04
# manual years_old            1432.1580    335.665      4.267      0.000     773.621    2090.695
# manual mileage per year       -5.7648      0.974     -5.919      0.000      -7.675      -3.854
# years_old^2                  228.2317     23.116      9.873      0.000     182.880     273.583
# years_old mileage per year    -0.3620      0.078     -4.656      0.000      -0.515      -0.209
# mileage per year^2             0.0003   6.93e-05      4.593      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                     1264.977   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           125616.195
# Skew:                           4.562   Prob(JB):                         0.00
# Kurtosis:                      51.295   Cond. No.                     6.12e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.44e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# Mean cv r^2: 0.787 +- 0.041
# Mean cv RMSE: 24011.137 +- 4095.562
# Mean cv MAE: 12653.070 +- 749.166

# %%
X_train_poly_6 = poly.fit_transform(X_non_test_6)

poly_non_test_6_df = pd.DataFrame(X_train_poly_6, columns = poly.get_feature_names(X_non_test_6.columns), index=X_non_test_6.index)

poly_non_test_6_df.to_pickle("./poly_non_test_6_df.pkl")
poly_non_test_6_df.head()
# Out:
#                    1  power  manual  years_old  mileage per year  \
# 202106224112829  1.0  325.0     1.0       15.0       4921.375000
# 202110148485474  1.0  350.0     1.0       15.0       1860.312500
# 202108246593754  1.0  250.0     1.0       31.0       2545.093750
# 202108236550132  1.0  365.0     1.0        3.0       4750.000000
# 202110268901845  1.0  365.0     1.0        5.0       3666.666667
#
#                  max_mph_per_bhp   power^2  power manual  power years_old  \
# 202106224112829         0.544615  105625.0         325.0           4875.0
# 202110148485474         0.520000  122500.0         350.0           5250.0
# 202108246593754         0.648000   62500.0         250.0           7750.0
# 202108236550132         0.501370  133225.0         365.0           1095.0
# 202110268901845         0.495890  133225.0         365.0           1825.0
#
#                  power mileage per year  ...  manual^2  manual years_old  \
# 202106224112829            1.599447e+06  ...       1.0              15.0
# 202110148485474            6.511094e+05  ...       1.0              15.0
# 202108246593754            6.362734e+05  ...       1.0              31.0
# 202108236550132            1.733750e+06  ...       1.0               3.0
# 202110268901845            1.338333e+06  ...       1.0               5.0
#
#                  manual mileage per year  manual max_mph_per_bhp  years_old^2  \
# 202106224112829              4921.375000                0.544615        225.0
# 202110148485474              1860.312500                0.520000        225.0
# 202108246593754              2545.093750                0.648000        961.0
# 202108236550132              4750.000000                0.501370          9.0
# 202110268901845              3666.666667                0.495890         25.0
#
#                  years_old mileage per year  years_old max_mph_per_bhp  \
# 202106224112829                73820.625000                   8.169231
# 202110148485474                27904.687500                   7.800000
# 202108246593754                78897.906250                  20.088000
# 202108236550132                14250.000000                   1.504110
# 202110268901845                18333.333333                   2.479452
#
#                  mileage per year^2  mileage per year max_mph_per_bhp  \
# 202106224112829        2.421993e+07                       2680.256538
# 202110148485474        3.460763e+06                        967.362500
# 202108246593754        6.477502e+06                       1649.220750
# 202108236550132        2.256250e+07                       2381.506849
# 202110268901845        1.344444e+07                       1818.264840
#
#                  max_mph_per_bhp^2
# 202106224112829           0.296606
# 202110148485474           0.270400
# 202108246593754           0.419904
# 202108236550132           0.251372
# 202110268901845           0.245907
#
# [5 rows x 21 columns]

# %%
evaluate(y_non_test, poly_non_test_6_df)
# Out:
#                            variables           vif
# 0                                  1  9.260148e+05
# 1                              power  2.959753e+04
# 2                             manual           inf
# 3                          years_old  1.164183e+04
# 4                   mileage per year  6.901165e+03
# 5                    max_mph_per_bhp  2.222732e+04
# 6                            power^2  7.131502e+03
# 7                       power manual  1.575492e+03
# 8                    power years_old  1.339780e+03
# 9             power mileage per year  1.102073e+03
# 10             power max_mph_per_bhp  5.539484e+02
# 11                          manual^2           inf
# 12                  manual years_old  1.800225e+01
# 13           manual mileage per year  8.272182e+00
# 14            manual max_mph_per_bhp  3.555588e+03
# 15                       years_old^2  4.238807e+01
# 16        years_old mileage per year  2.106733e+01
# 17         years_old max_mph_per_bhp  6.521750e+03
# 18                mileage per year^2  5.958065e+00
# 19  mileage per year max_mph_per_bhp  2.984904e+03
# 20                 max_mph_per_bhp^2  9.243540e+03
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     305.3
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:44:59   Log-Likelihood:                -14241.
# No. Observations:                1248   AIC:                         2.852e+04
# Df Residuals:                    1228   BIC:                         2.862e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# 1                                 8.219e+04      6e+05      0.137      0.891   -1.09e+06    1.26e+06
# power                               26.2471   1403.711      0.019      0.985   -2727.691    2780.185
# manual                           -2.829e+05   6.71e+04     -4.217      0.000   -4.15e+05   -1.51e+05
# years_old                         8789.9389   1.01e+04      0.872      0.383    -1.1e+04    2.86e+04
# mileage per year                   -56.2524     26.740     -2.104      0.036    -108.714      -3.791
# max_mph_per_bhp                   1.341e+06   1.42e+06      0.943      0.346   -1.45e+06    4.13e+06
# power^2                              0.6548      0.788      0.831      0.406      -0.891       2.201
# power manual                       787.9713    144.918      5.437      0.000     503.657    1072.285
# power years_old                    -25.5824     10.571     -2.420      0.016     -46.322      -4.843
# power mileage per year               0.0145      0.027      0.543      0.587      -0.038       0.067
# power max_mph_per_bhp            -1742.6363   1674.134     -1.041      0.298   -5027.115    1541.843
# manual^2                         -2.829e+05   6.71e+04     -4.217      0.000   -4.15e+05   -1.51e+05
# manual years_old                   826.3709    371.314      2.226      0.026      97.890    1554.851
# manual mileage per year             -4.7848      1.003     -4.771      0.000      -6.752      -2.817
# manual max_mph_per_bhp            5.798e+05   1.63e+05      3.555      0.000     2.6e+05       9e+05
# years_old^2                        237.5873     25.547      9.300      0.000     187.466     287.709
# years_old mileage per year          -0.5485      0.092     -5.991      0.000      -0.728      -0.369
# years_old max_mph_per_bhp        -1.115e+04   1.31e+04     -0.850      0.395   -3.69e+04    1.46e+04
# mileage per year^2                   0.0004    7.1e-05      5.593      0.000       0.000       0.001
# mileage per year max_mph_per_bhp   101.8050     34.986      2.910      0.004      33.166     170.444
# max_mph_per_bhp^2                -1.733e+06    9.7e+05     -1.786      0.074   -3.64e+06    1.71e+05
# ==============================================================================
# Omnibus:                     1257.175   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           125923.423
# Skew:                           4.508   Prob(JB):                         0.00
# Kurtosis:                      51.377   Cond. No.                     3.54e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.27e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# Mean cv r^2: 0.804 +- 0.045
# Mean cv RMSE: 23057.297 +- 4504.481
# Mean cv MAE: 12456.816 +- 514.013

# %%
poly_3 = PolynomialFeatures(degree=3)

# Fit polynomial features and transform on training data
X_train_poly_3 = poly_3.fit_transform(X_non_test_5)

poly_3_df = pd.DataFrame(X_train_poly_3, columns = poly_3.get_feature_names(X_non_test_5.columns), index=X_non_test_5.index)
poly_3_df.head()
# Out:
#                    1  power  manual  years_old  mileage per year   power^2  \
# 202106224112829  1.0  325.0     1.0       15.0       4921.375000  105625.0
# 202110148485474  1.0  350.0     1.0       15.0       1860.312500  122500.0
# 202108246593754  1.0  250.0     1.0       31.0       2545.093750   62500.0
# 202108236550132  1.0  365.0     1.0        3.0       4750.000000  133225.0
# 202110268901845  1.0  365.0     1.0        5.0       3666.666667  133225.0
#
#                  power manual  power years_old  power mileage per year  \
# 202106224112829         325.0           4875.0            1.599447e+06
# 202110148485474         350.0           5250.0            6.511094e+05
# 202108246593754         250.0           7750.0            6.362734e+05
# 202108236550132         365.0           1095.0            1.733750e+06
# 202110268901845         365.0           1825.0            1.338333e+06
#
#                  manual^2  ...  manual^3  manual^2 years_old  \
# 202106224112829       1.0  ...       1.0                15.0
# 202110148485474       1.0  ...       1.0                15.0
# 202108246593754       1.0  ...       1.0                31.0
# 202108236550132       1.0  ...       1.0                 3.0
# 202110268901845       1.0  ...       1.0                 5.0
#
#                  manual^2 mileage per year  manual years_old^2  \
# 202106224112829                4921.375000               225.0
# 202110148485474                1860.312500               225.0
# 202108246593754                2545.093750               961.0
# 202108236550132                4750.000000                 9.0
# 202110268901845                3666.666667                25.0
#
#                  manual years_old mileage per year  manual mileage per year^2  \
# 202106224112829                       73820.625000               2.421993e+07
# 202110148485474                       27904.687500               3.460763e+06
# 202108246593754                       78897.906250               6.477502e+06
# 202108236550132                       14250.000000               2.256250e+07
# 202110268901845                       18333.333333               1.344444e+07
#
#                  years_old^3  years_old^2 mileage per year  \
# 202106224112829       3375.0                  1.107309e+06
# 202110148485474       3375.0                  4.185703e+05
# 202108246593754      29791.0                  2.445835e+06
# 202108236550132         27.0                  4.275000e+04
# 202110268901845        125.0                  9.166667e+04
#
#                  years_old mileage per year^2  mileage per year^3
# 202106224112829                  3.632990e+08        1.191954e+11
# 202110148485474                  5.191144e+07        6.438100e+09
# 202108246593754                  2.008026e+08        1.648585e+10
# 202108236550132                  6.768750e+07        1.071719e+11
# 202110268901845                  6.722222e+07        4.929630e+10
#
# [5 rows x 35 columns]

# %%
evaluate(y_non_test, poly_3_df)
# Out:
#                             variables           vif
# 0                                   1  0.000000e+00
# 1                               power  3.366463e+04
# 2                              manual  2.124339e+13
# 3                           years_old  2.927299e+04
# 4                    mileage per year  7.021001e+03
# 5                             power^2  9.179882e+04
# 6                        power manual  1.501200e+15
# 7                     power years_old  4.431125e+04
# 8              power mileage per year  1.513706e+04
# 9                            manual^2  1.396106e+10
# 10                   manual years_old  1.286743e+15
# 11            manual mileage per year           inf
# 12                        years_old^2  1.051569e+04
# 13         years_old mileage per year  2.771551e+03
# 14                 mileage per year^2  1.652222e+03
# 15                            power^3  1.684064e+04
# 16                     power^2 manual  4.678002e+03
# 17                  power^2 years_old  5.703081e+03
# 18           power^2 mileage per year  2.712685e+03
# 19                     power manual^2           inf
# 20             power manual years_old  1.004522e+03
# 21      power manual mileage per year  5.332158e+02
# 22                  power years_old^2  3.400859e+03
# 23   power years_old mileage per year  1.073329e+03
# 24           power mileage per year^2  1.103454e+03
# 25                           manual^3  8.944054e+10
# 26                 manual^2 years_old  3.336000e+14
# 27          manual^2 mileage per year           inf
# 28                 manual years_old^2  1.771132e+02
# 29  manual years_old mileage per year  8.638394e+01
# 30          manual mileage per year^2  4.038814e+01
# 31                        years_old^3  5.611273e+02
# 32       years_old^2 mileage per year  1.974239e+02
# 33       years_old mileage per year^2  1.561469e+02
# 34                 mileage per year^3  5.951592e+01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0
Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           115438.279
# Skew:                           4.098   Prob(JB):                         0.00
# Kurtosis:                      49.398   Cond. No.                     1.04e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Mean cv r^2: 0.549 +- 0.555
# Mean cv RMSE: 30062.670 +- 17151.417
# Mean cv MAE: 12252.022 +- 2198.435

# %%
evaluate(log_y, poly_non_test_6_df)
# Out:
#                            variables           vif
# 0                                  1  9.260148e+05
# 1                              power  2.959753e+04
# 2                             manual           inf
# 3                          years_old  1.164183e+04
# 4                   mileage per year  6.901165e+03
# 5                    max_mph_per_bhp  2.222732e+04
# 6                            power^2  7.131502e+03
# 7                       power manual  1.575492e+03
# 8                    power years_old  1.339780e+03
# 9             power mileage per year  1.102073e+03
# 10             power max_mph_per_bhp  5.539484e+02
# 11                          manual^2           inf
# 12                  manual years_old  1.800225e+01
# 13           manual mileage per year  8.272182e+00
# 14            manual max_mph_per_bhp  3.555588e+03
# 15                       years_old^2  4.238807e+01
# 16        years_old mileage per year  2.106733e+01
# 17         years_old max_mph_per_bhp  6.521750e+03
# 18                mileage per year^2  5.958065e+00
# 19  mileage per year max_mph_per_bhp  2.984904e+03
# 20                 max_mph_per_bhp^2  9.243540e+03
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     577.4
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:45:01   Log-Likelihood:                 188.72
# No. Observations:                1248   AIC:                            -337.4
# Df Residuals:                    1228   BIC:                            -234.9
# Df Model:                          19
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# 1                                   26.6424      5.712      4.664      0.000      15.436      37.849
# power                               -0.0267      0.013     -1.997      0.046      -0.053      -0.000
# manual                              -2.0206      0.639     -3.163      0.002      -3.274      -0.767
# years_old                           -0.4256      0.096     -4.434      0.000      -0.614      -0.237
# mileage per year                 -1.046e-05      0.000     -0.041      0.967      -0.001       0.000
# max_mph_per_bhp                    -21.1121     13.548     -1.558      0.119     -47.691       5.467
# power^2                           1.635e-05    7.5e-06      2.180      0.029    1.63e-06    3.11e-05
# power manual                         0.0055      0.001      3.982      0.000       0.003       0.008
# power years_old                      0.0004      0.000      3.786      0.000       0.000       0.001
# power mileage per year           -2.077e-07   2.53e-07     -0.819      0.413   -7.05e-07     2.9e-07
# power max_mph_per_bhp                0.0135      0.016      0.847      0.397      -0.018       0.045
# manual^2                            -2.0206      0.639     -3.163      0.002      -3.274      -0.767
# manual years_old                     0.0114      0.004      3.224      0.001       0.004       0.018
# manual mileage per year          -2.491e-05   9.55e-06     -2.608      0.009   -4.36e-05   -6.17e-06
# manual max_mph_per_bhp               4.0481      1.553      2.607      0.009       1.002       7.094
# years_old^2                          0.0031      0.000     12.833      0.000       0.003       0.004
# years_old mileage per year       -1.101e-05   8.72e-07    -12.635      0.000   -1.27e-05    -9.3e-06
# years_old max_mph_per_bhp            0.4087      0.125      3.274      0.001       0.164       0.654
# mileage per year^2                4.779e-09   6.76e-10      7.069      0.000    3.45e-09    6.11e-09
# mileage per year max_mph_per_bhp     0.0002      0.000      0.571      0.568      -0.000       0.001
# max_mph_per_bhp^2                    2.1253      9.237      0.230      0.818     -15.996      20.247
# ==============================================================================
# Omnibus:                      366.743   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2224.808
# Skew:                           1.218   Prob(JB):                         0.00
# Kurtosis:                       9.071   Cond. No.                     3.54e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.27e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# Mean cv r^2: 0.595 +- 0.590
# Mean cv RMSE: 0.347 +- 0.269
# Mean cv MAE: 0.160 +- 0.030

# %%
X_train_poly_5, X_val_poly_5, y_train_poly_5, y_val_poly_5 = train_test_split(poly_non_test_5_df, y_non_test, test_size=.25)

# %%
X_train_poly_6, X_val_poly_6, y_train_poly_6, y_val_poly_6 = train_test_split(poly_non_test_6_df, y_non_test, test_size=.25)

# %%
log_y_train = np.log(y_train_poly_5)
results = simple_lr(log_y_train, X_train_poly_5)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                     629.9
# Date:                Tue, 09 Nov 2021   Prob (F-statistic):               0.00
# Time:                        15:45:02   Log-Likelihood:                 137.72
# No. Observations:                 936   AIC:                            -247.4
# Df Residuals:                     922   BIC:                            -179.7
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# 1                              9.6867      0.493     19.656      0.000       8.719      10.654
# power                          0.0066      0.002      3.516      0.000       0.003       0.010
# manual                        -0.3564      0.096     -3.730      0.000      -0.544      -0.169
# years_old                     -0.1280      0.019     -6.918      0.000      -0.164      -0.092
# mileage per year               0.0001   3.47e-05      4.064      0.000    7.29e-05       0.000
# power^2                    -3.508e-06   1.78e-06     -1.966      0.050   -7.01e-06   -6.29e-09
# power manual                   0.0019      0.000      5.022      0.000       0.001       0.003
# power years_old              9.23e-05   3.47e-05      2.659      0.008    2.42e-05       0.000
# power mileage per year     -3.578e-07   7.07e-08     -5.063      0.000   -4.96e-07   -2.19e-07
# manual^2                      -0.3564      0.096     -3.730      0.000      -0.544      -0.169
# manual years_old               0.0128      0.004      3.414      0.001       0.005       0.020
# manual mileage per year    -3.027e-05   1.06e-05     -2.861      0.004    -5.1e-05   -9.51e-06
# years_old^2                    0.0036      0.000     14.120      0.000       0.003       0.004
# years_old mileage per year  -1.14e-05   8.49e-07    -13.427      0.000   -1.31e-05   -9.73e-06
# mileage per year^2          4.854e-09   6.87e-10      7.069      0.000    3.51e-09     6.2e-09
# ==============================================================================
# Omnibus:                      319.337   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2583.609
# Skew:                           1.328   Prob(JB):                         0.00
# Kurtosis:                      10.694   Cond. No.                     3.89e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  5e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
mae = sum(abs(np.exp(results.predict(X_val_poly_5)) - y_val_poly_5))/len(y_val_poly_5)
mae
# Out:
# 12944.840682832868

# %%
f, (ax0, ax1) = plt.subplots(1, 2)

ax0.hist(y_non_test, bins=100)
ax0.set_xlim([0, 200000])
ax0.set_ylabel("Probability")
ax0.set_xlabel("Target")
ax0.set_title("Target distribution")

ax1.hist(log_y, bins=100)
ax1.set_ylabel("Probability")
ax1.set_xlabel("Target")
ax1.set_title("Transformed target distribution")

f.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])

# %%
from sklearn.linear_model import RidgeCV
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import median_absolute_error, r2_score

regr_trans = TransformedTargetRegressor(
    regressor=LinearRegression(), func=np.log1p, inverse_func=np.expm1
)

regr_trans.fit(X_train_poly_5, y_train_poly_5)
y_pred = regr_trans.predict(X_val_poly_5)

# %%
r2_score(y_val_poly_5, y_pred)
# Out:
# 0.7988343006311086

# %%
median_absolute_error(y_val_poly_5, y_pred)
# Out:
# 6539.924664315642

# %%
mean_absolute_error(y_val_poly_5, y_pred)
# Out:
# 12944.7978939945

# %%
from sklearn.preprocessing import QuantileTransformer, quantile_transform

y_trans = quantile_transform(
    y_non_test.to_frame(), n_quantiles=900, output_distribution="normal", copy=True
).squeeze()

# %%
f, (ax0, ax1) = plt.subplots(1, 2)

ax0.hist(y_non_test, bins=100)
ax0.set_ylabel("Probability")
ax0.set_xlabel("Target")
ax0.set_title("Target distribution")
ax0.ticklabel_format(axis="both", style="sci", scilimits=(0, 0))

ax1.hist(y_trans, bins=100)
ax1.set_ylabel("Probability")
ax1.set_xlabel("Target")
ax1.set_title("Transformed target distribution")

f.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])

# %%
from sklearn.preprocessing import power_transform

y_trans_power = power_transform(
    y_non_test.to_frame(), method='box-cox', copy=True
).squeeze()

# %%
f, (ax0, ax1) = plt.subplots(1, 2)

ax0.hist(y_non_test, bins=100)
ax0.set_ylabel("Probability")
ax0.set_xlabel("Target")
ax0.set_title("Target distribution")
ax0.ticklabel_format(axis="both", style="sci", scilimits=(0, 0))

ax1.hist(y_trans_power, bins=100)
ax1.set_ylabel("Probability")
ax1.set_xlabel("Target")
ax1.set_title("Transformed target distribution")

f.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])

# %%
X_train_5, X_val_5, y_train_5, y_val_5 = train_test_split(X_non_test_5, y_non_test, test_size=.25)

# %%
regr_trans = TransformedTargetRegressor(
    regressor=RidgeCV(),
    transformer=QuantileTransformer(n_quantiles=900, output_distribution="normal"),
)
regr_trans.fit(X_train_5, y_train_5)
y_pred_5 = regr_trans.predict(X_val_5)

# %%
r2_score(y_val_5, y_pred_5)
# Out:
# 0.6393392805669555

# %%
median_absolute_error(y_val_5, y_pred_5)
# Out:
# 6924.387599506583

# %%
mean_absolute_error(y_val_5, y_pred_5)
# Out:
# 15278.542888317239

# %%
sns.scatterplot(x=y_val_5, y=y_pred_5)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
fig = sns.scatterplot(x=y_pred_5, y=(y_pred_5-y_val_5))
fig.set_ylabel("residual")
fig.set_xlabel("predicted price")
# Out:
# Text(0.5, 0, 'predicted price')

# %%
plt.figure(figsize=(8, 5))
sns.distplot((y_pred_5-y_val_5))
plt.xlabel('Target Residuals', size=14)
sns.despine()
plt.title('Distribution of Residuals', size=16)
# Out:
# Text(0.5, 1.0, 'Distribution of Residuals')

# %%
regr_trans = TransformedTargetRegressor(
    regressor=LinearRegression(),
    transformer=QuantileTransformer(n_quantiles=900, output_distribution="normal"),
)
regr_trans.fit(X_train_poly_5, y_train_poly_5)
y_pred_Q = regr_trans.predict(X_val_poly_5)

# %%
r2_score(y_val_poly_5, y_pred_Q)
# Out:
# 0.792703628019409

# %%
median_absolute_error(y_val_poly_5, y_pred_Q)
# Out:
# 6524.314028247991

# %%
mean_absolute_error(y_val_poly_5, y_pred_Q)
# Out:
# 13189.961171385634

# %%
sns.scatterplot(x=y_val_poly_5, y=y_pred_Q)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.regplot(x=y_val_poly_5, y=y_pred_Q)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.scatterplot(x=y_pred_Q, y=(y_pred_Q-y_val_poly_5))
# Out:
# <AxesSubplot:ylabel='price'>

# %%
stats.probplot(y_pred_Q-y_val_poly_5, dist="norm", plot=plt)
# Out:
# ((array([-2.84520254, -2.54998829, -2.38293086, -2.26393382, -2.17034194,
#          -2.09261297, -2.0257883 , -1.96694762, -1.91422028, -1.86633306,
#          -1.82237868, -1.78168684, -1.74374778, -1.70816438, -1.67462102,
#          -1.64286254, -1.61267956, -1.5838981 , -1.55637193, -1.52997692,
#          -1.50460676, -1.48016967, -1.45658584, -1.43378542, -1.41170693,
#          -1.39029592, -1.36950394, -1.34928772, -1.32960838, -1.31043091,
#          -1.29172364, -1.27345781, -1.25560726, -1.23814806, -1.22105834,
#          -1.20431799, -1.18790849, -1.17181278, -1.15601506, -1.1405007 ,
#          -1.1252561 , -1.11026861, -1.09552646, -1.08101863, -1.06673484,
#          -1.05266543, -1.03880137, -1.02513416, -1.0116558 , -0.99835876,
#          -0.98523595, -0.97228064, -0.9594865 , -0.94684752, -0.93435801,
#          -0.92201257, -0.90980609, -0.89773368, -0.88579071, -0.87397277,
#          -0.86227565, -0.85069534, -0.839228  , -0.82786997, -0.81661774,
#          -0.80546798, -0.79441746, -0.78346311, -0.77260197, -0.76183123,
#          -0.75114814, -0.7405501 , -0.73003459, -0.7195992 , -0.70924159,
#          -0.69895951, -0.6887508 , -0.67861337, -0.66854521, -0.65854436,
#          -0.64860895, -0.63873716, -0.62892723, -0.61917745, -0.60948618,
#          -0.59985182, -0.59027281, -0.58074767, -0.57127493, -0.56185317,
#          -0.55248103, -0.54315717, -0.53388029, -0.52464913, -0.51546247,
#          -0.5063191 , -0.49721787, -0.48815764, -0.4791373 , -0.47015578,
#          -0.46121204, -0.45230503, -0.44343376, -0.43459726, -0.42579456,
#          -0.41702473, -0.40828686, -0.39958005, -0.39090343, -0.38225614,
#          -0.37363734, -0.36504621, -0.35648193, -0.34794373, -0.33943081,
#          -0.33094242, -0.32247781, -0.31403625, -0.305617  , -0.29721936,
#          -0.28884263, -0.28048612, -0.27214915, -0.26383105, -0.25553117,
#          -0.24724886, -0.23898347, -0.23073437, -0.22250095, -0.21428258,
#          -0.20607866, -0.19788859, -0.18971177, -0.18154761, -0.17339554,
#           2.99990460e+04,  3.22404088e+04,  3.38255415e+04,  3.49958352e+04,
#           3.75504071e+04,  4.19650000e+04,  4.26630118e+04,  5.83075134e+04])),
#  (21012.531468219797, -3451.57887362779, 0.8207829828084667))

# %%
plt.figure(figsize=(8, 5))
sns.distplot((y_pred_Q-y_val_poly_5))
plt.xlabel('Target Residuals', size=14)
sns.despine()
plt.title('Distribution of Residuals', size=16)
# Out:
# Text(0.5, 1.0, 'Distribution of Residuals')

# %%
regr_trans = TransformedTargetRegressor(
    regressor=LinearRegression(),
    transformer=QuantileTransformer(n_quantiles=900, output_distribution="normal"),
)
regr_trans.fit(X_train_poly_6, y_train_poly_6)
y_pred_Q = regr_trans.predict(X_val_poly_6)

# %%
r2_score(y_val_poly_6, y_pred_Q)
# Out:
# 0.8046554912816715

# %%
mean_absolute_error(y_val_poly_6, y_pred_Q)
# Out:
# 10457.053526182282

# %%
X_train_poly_2 = poly.fit_transform(X_non_test)

poly_non_test_df = pd.DataFrame(X_train_poly_2, columns = poly.get_feature_names(X_non_test.columns), index=X_non_test.index)

poly_non_test_df.to_pickle(("./poly_non_test_df.pkl"))

# %%
X_test_poly_2 = poly.fit_transform(X_test)

poly_test_df = pd.DataFrame(X_test_poly_2, columns = poly.get_feature_names(X_test.columns), index=X_test.index)

# %%
vifs(poly_non_test_df)
# Out:
#                   variables           vif
# 0                         1  0.000000e+00
# 1                   mileage  1.826602e+04
# 2               engine_size  3.652901e+04
# 3                   0-6Xmph  1.316327e+05
# 4                 top_speed  1.492249e+04
# 5                     power  8.441111e+04
# 6               convertible           inf
# 7                    manual           inf
# 8                 years_old  3.482383e+04
# 9                 mileage^2  1.022903e+01
# 10      mileage engine_size  1.427353e+03
# 11          mileage 0-6Xmph  1.497212e+03
# 12        mileage top_speed  1.863499e+04
# 13            mileage power  1.142132e+03
# 14      mileage convertible  9.781443e+00
# 15           mileage manual  1.675022e+01
# 16        mileage years_old  1.099627e+02
# 17            engine_size^2  1.005184e+04
# 18      engine_size 0-6Xmph  9.175838e+03
# 19    engine_size top_speed  4.024743e+04
# 20        engine_size power  2.301184e+04
# 21  engine_size convertible  3.982230e+02
# 22       engine_size manual  5.372061e+02
# 23    engine_size years_old  3.626998e+03
# 24                0-6Xmph^2  2.125576e+04
# 25        0-6Xmph top_speed  4.413540e+04
# 26            0-6Xmph power  1.790789e+03
# 27      0-6Xmph convertible  7.339261e+02
# 28           0-6Xmph manual  2.334904e+03
# 29        0-6Xmph years_old  5.030709e+03
# 30              top_speed^2  4.617065e+03
# 31          top_speed power  9.448533e+04
# 32    top_speed convertible  9.643585e+03
# 33         top_speed manual  1.074799e+04
# 34      top_speed years_old  2.700509e+04
# 35                  power^2  1.265628e+04
# 36        power convertible  7.368696e+02
# 37             power manual  1.155914e+03
# 38          power years_old  1.861743e+03
# 39            convertible^2  9.007199e+15
# 40       convertible manual  3.331818e+00
# 41    convertible years_old  2.264340e+01
# 42                 manual^2  7.848043e+11
# 43         manual years_old  3.510998e+01
# 44              years_old^2  2.467385e+02

# %%
def cv_regression(X, y, regr):
    kf = KFold(n_splits=10, shuffle=True)

    train_r2s, train_rmses, train_maes = [], [], []
    r2s, rmses, maes = [], [], []
    for train_ind, val_ind in kf.split(X,y):
        X_train, y_train = X.iloc[train_ind], y.iloc[train_ind]
        X_val, y_val = X.iloc[val_ind], y.iloc[val_ind]
        regr.fit(X_train, y_train)

        train_r2s.append(regr.score(X_train, y_train))
        train_rmses.append(mean_squared_error(y_train, regr.predict(X_train), squared=False))
        train_maes.append(mean_absolute_error(y_train, regr.predict(X_train)))

        r2s.append(regr.score(X_val, y_val))
        rmses.append(mean_squared_error(y_val, regr.predict(X_val), squared=False))
        maes.append(mean_absolute_error(y_val, regr.predict(X_val)))

    print(f'\n\nMean train cv r^2: {np.mean(train_r2s):.3f} +- {np.std(train_r2s):.3f}')
    print(f'Mean train cv RMSE: {np.mean(train_rmses):.3f} +- {np.std(train_rmses):.3f}')
    print(f'Mean train cv MAE: {np.mean(train_maes):.3f} +- {np.std(train_maes):.3f}')

    print(f'\n\nMean val cv r^2: {np.mean(r2s):.3f} +- {np.std(r2s):.3f}')
    print(f'Mean val cv RMSE: {np.mean(rmses):.3f} +- {np.std(rmses):.3f}')
    print(f'Mean val cv MAE: {np.mean(maes):.3f} +- {np.std(maes):.3f}')

    return regr

# %%
regr = TransformedTargetRegressor(
    regressor=LinearRegression(),
    transformer=PowerTransformer(method='box-cox'),
)

regressor = cv_regression(poly_non_test_df, y_non_test, regr)
regressor
# Out:
# Mean train cv r^2: 0.889 +- 0.009
# Mean train cv RMSE: 17441.615 +- 863.561
# Mean train cv MAE: 8176.253 +- 114.221
#
#
# Mean val cv r^2: 0.884 +- 0.067
# Mean val cv RMSE: 17185.121 +- 7007.148
# Mean val cv MAE: 8579.944 +- 1183.115
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
y_test_pred = regressor.predict(poly_test_df)

mean_absolute_error(y_test, y_test_pred)
# Out:
# 7813.629884401572

# %%
regressor.score(poly_test_df, y_test)
# Out:
# 0.8534602342849077

# %%
fig = sns.scatterplot(x=y_test_pred, y=(y_test_pred-y_test))
fig.set_ylabel("residual")
fig.set_xlabel("predicted price")
# Out:
# Text(0.5, 0, 'predicted price')

# %%
stats.probplot(y_test_pred-y_test, dist="norm", plot=plt)
# Out:
# ((array([-2.84520254, -2.54998829, -2.38293086, -2.26393382, -2.17034194,
#          -2.09261297, -2.0257883 , -1.96694762, -1.91422028, -1.86633306,
#          -1.82237868, -1.78168684, -1.74374778, -1.70816438, -1.67462102,
#          -1.64286254, -1.61267956, -1.5838981 , -1.55637193, -1.52997692,
#          -1.50460676, -1.48016967, -1.45658584, -1.43378542, -1.41170693,
#          -1.39029592, -1.36950394, -1.34928772, -1.32960838, -1.31043091,
#          -1.29172364, -1.27345781, -1.25560726, -1.23814806, -1.22105834,
#          -1.20431799, -1.18790849, -1.17181278, -1.15601506, -1.1405007 ,
#           5.60326746e+03,  5.62578209e+03,  5.62620068e+03,  5.66872475e+03,
#           5.82940185e+03,  5.87731484e+03,  5.91935397e+03,  5.99585772e+03,
#           6.06901128e+03,  6.15980541e+03,  6.16138934e+03,  6.19847494e+03,
#           6.25515066e+03,  6.27747035e+03,  6.28967446e+03,  6.43325681e+03,
#           6.51038293e+03,  6.77406579e+03,  6.82642694e+03,  6.96511732e+03,
#           7.10771374e+03,  7.24257584e+03,  7.36829787e+03,  7.46277488e+03,
#           7.58730691e+03,  7.67831285e+03,  7.74979281e+03,  7.80608955e+03,
#           7.98311732e+03,  8.00664861e+03,  8.40122773e+03,  8.44904263e+03,
#           8.58146994e+03,  8.68604807e+03,  8.81713587e+03,  8.98846302e+03,
#           8.99719628e+03,  9.12711041e+03,  9.27484728e+03,  9.35909982e+03,
#           9.52678772e+03,  9.54497544e+03,  9.69240177e+03,  9.82930453e+03,
#           9.84791596e+03,  1.00549261e+04,  1.00655891e+04,  1.02374326e+04,
#           1.02510080e+04,  1.03248949e+04,  1.04241412e+04,  1.04340593e+04,
#           1.06492186e+04,  1.11378719e+04,  1.12140054e+04,  1.14632850e+04,
#           1.15418209e+04,  1.20099832e+04,  1.23673311e+04,  1.26431452e+04,
#           1.28599882e+04,  1.30519486e+04,  1.31591938e+04,  1.32293722e+04,
#           1.47591805e+04,  1.47614835e+04,  1.48022270e+04,  1.54084258e+04,
#           1.66905868e+04,  1.72708418e+04,  1.75207642e+04,  1.77317539e+04,
#           1.78969717e+04,  1.94135180e+04,  2.03251155e+04,  2.05911117e+04,
#           2.46721660e+04,  3.61025084e+04,  4.25919991e+04,  5.01626276e+04])),
#  (12265.363674532973, -528.9399068909854, 0.5995121429665548))

# %%
fig = sns.scatterplot(x=y_test, y=y_test_pred)
fig.set_ylabel("predicted price")
fig.set_xlabel("price")

# %%
cv_regression(poly_non_test_5_df, y_non_test, regr)
# Out:
# Mean train cv r^2: 0.819 +- 0.007
# Mean train cv RMSE: 22225.732 +- 563.024
# Mean train cv MAE: 11402.326 +- 65.525
#
#
# Mean val cv r^2: 0.814 +- 0.059
# Mean val cv RMSE: 22252.051 +- 4753.960
# Mean val cv MAE: 11614.305 +- 739.368
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
cv_regression(poly_non_test_6_df, y_non_test, regr)
# Out:
# Mean train cv r^2: 0.828 +- 0.011
# Mean train cv RMSE: 21693.385 +- 961.115
# Mean train cv MAE: 11110.132 +- 248.019
#
#
# Mean val cv r^2: 0.824 +- 0.076
# Mean val cv RMSE: 21591.057 +- 7347.701
# Mean val cv MAE: 11471.661 +- 1944.452
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
cv_regression(X_non_test_5, y_non_test, regr)
# Out:
# Mean train cv r^2: 0.738 +- 0.012
# Mean train cv RMSE: 26751.507 +- 1012.315
# Mean train cv MAE: 13912.018 +- 526.079
#
#
# Mean val cv r^2: 0.748 +- 0.103
# Mean val cv RMSE: 25630.117 +- 8739.915
# Mean val cv MAE: 14069.268 +- 2784.528
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
cv_regression(X_non_test, y_non_test, regr)
# Out:
# Mean train cv r^2: 0.721 +- 0.009
# Mean train cv RMSE: 27611.229 +- 637.349
# Mean train cv MAE: 13268.571 +- 244.518
#
#
# Mean val cv r^2: 0.486 +- 0.712
# Mean val cv RMSE: 33033.072 +- 18414.462
# Mean val cv MAE: 14237.356 +- 3543.137
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
regr2 = TransformedTargetRegressor(
    regressor=LinearRegression(),
    transformer=QuantileTransformer(n_quantiles=900, output_distribution="normal"),
)

regressorQ = cv_regression(poly_non_test_df, y_non_test, regr2)
# Out:
# Mean train cv r^2: 0.880 +- 0.013
# Mean train cv RMSE: 18089.869 +- 1076.247
# Mean train cv MAE: 8867.710 +- 609.373
#
#
# Mean val cv r^2: 0.865 +- 0.083
# Mean val cv RMSE: 18509.014 +- 6815.605
# Mean val cv MAE: 9461.939 +- 1160.398

# %%
y_test_pred_Q = regressorQ.predict(poly_test_df)

mean_absolute_error(y_test, y_test_pred_Q)
# Out:
# 8543.750700336477

# %%
regressorQ.score(poly_test_df, y_test)
# Out:
# 0.8542560131664676

# %%
stats.probplot(y_test_pred_Q-y_test, dist="norm", plot=plt)
# Out:
# ((array([-2.84520254, -2.54998829, -2.38293086, -2.26393382, -2.17034194,
#          -2.09261297, -2.0257883 , -1.96694762, -1.91422028, -1.86633306,
#          -1.82237868, -1.78168684, -1.74374778, -1.70816438, -1.67462102,
#          -1.64286254, -1.61267956, -1.5838981 , -1.55637193, -1.52997692,
#          -1.50460676, -1.48016967, -1.45658584, -1.43378542, -1.41170693,
#          -1.39029592, -1.36950394, -1.34928772, -1.32960838, -1.31043091,
#          -1.29172364, -1.27345781, -1.25560726, -1.23814806, -1.22105834,
#          -1.20431799, -1.18790849, -1.17181278, -1.15601506, -1.1405007 ,
#          -1.1252561 , -1.11026861, -1.09552646, -1.08101863, -1.06673484,
#          -1.05266543, -1.03880137, -1.02513416, -1.0116558 , -0.99835876,
#          -0.98523595, -0.97228064, -0.9594865 , -0.94684752, -0.93435801,
#          -0.92201257, -0.90980609, -0.89773368, -0.88579071, -0.87397277,
#          -0.86227565, -0.85069534, -0.839228  , -0.82786997, -0.81661774,
#          -0.80546798, -0.79441746, -0.78346311, -0.77260197, -0.76183123,
#          -0.75114814, -0.7405501 , -0.73003459, -0.7195992 , -0.70924159,
#          -0.69895951, -0.6887508 , -0.67861337, -0.66854521, -0.65854436,
#          -0.64860895, -0.63873716, -0.62892723, -0.61917745, -0.60948618,
#          -0.59985182, -0.59027281, -0.58074767, -0.57127493, -0.56185317,
#          -0.55248103, -0.54315717, -0.53388029, -0.52464913, -0.51546247,
#          -0.5063191 , -0.49721787, -0.48815764, -0.4791373 , -0.47015578,
#          -0.46121204, -0.45230503, -0.44343376, -0.43459726, -0.42579456,
#          -0.41702473, -0.40828686, -0.39958005, -0.39090343, -0.38225614,
#           1.20000000e+04,  1.24627623e+04,  1.24802233e+04,  1.30350185e+04,
#           1.32418240e+04,  1.40076495e+04,  1.41676782e+04,  1.46711915e+04,
#           1.47799667e+04,  1.50126911e+04,  1.55464589e+04,  1.60000090e+04,
#           1.68437833e+04,  1.70127967e+04,  1.79610184e+04,  1.80759194e+04,
#           1.89657436e+04,  1.97848519e+04,  2.10486090e+04,  2.25267231e+04,
#           2.47820998e+04,  2.49285434e+04,  2.50473625e+04,  2.64950000e+04,
#           3.50026063e+04,  6.49577217e+04,  6.77586231e+04,  6.99725170e+04])),
#  (13647.438087269982, -221.81802585707433, 0.6451449352708333))

# %%
fig = sns.scatterplot(x=y_test, y=(y_test_pred_Q-y_test))
fig.set_ylabel("residual")
fig.set_xlabel("predicted price")
# Out:
# Text(0.5, 0, 'predicted price')

# %%
fig = sns.scatterplot(x=y_test, y=y_test_pred_Q)
fig.set_ylabel("predicted price")
fig.set_xlabel("price")
# Out:
# Text(0.5, 0, 'predicted price')

# %%
cv_regression(poly_non_test_5_df, y_non_test, regr2)
# Out:
# Mean train cv r^2: 0.821 +- 0.012
# Mean train cv RMSE: 22099.066 +- 981.741
# Mean train cv MAE: 11072.142 +- 146.312
#
#
# Mean val cv r^2: 0.825 +- 0.083
# Mean val cv RMSE: 21568.656 +- 6791.704
# Mean val cv MAE: 11334.034 +- 1364.679
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=QuantileTransformer(n_quantiles=900,
#                                                            output_distribution='normal'))

# %%
cv_regression(poly_non_test_6_df, y_non_test, regr2)
# Out:
# Mean train cv r^2: 0.821 +- 0.008
# Mean train cv RMSE: 22121.046 +- 750.570
# Mean train cv MAE: 10879.334 +- 141.577
#
#
# Mean val cv r^2: 0.812 +- 0.050
# Mean val cv RMSE: 22353.994 +- 5386.607
# Mean val cv MAE: 11287.702 +- 775.910
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=QuantileTransformer(n_quantiles=900,
#                                                            output_distribution='normal'))

# %%
cv_regression(X_non_test_5, y_non_test, regr2)
# Out:
# Mean train cv r^2: 0.727 +- 0.018
# Mean train cv RMSE: 27306.343 +- 1163.998
# Mean train cv MAE: 13923.067 +- 286.306
#
#
# Mean val cv r^2: 0.739 +- 0.106
# Mean val cv RMSE: 26203.054 +- 8200.896
# Mean val cv MAE: 14051.835 +- 2231.477
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=QuantileTransformer(n_quantiles=900,
#                                                            output_distribution='normal'))

# %%
cv_regression(X_non_test, y_non_test, regr2)
# Out:
# Mean train cv r^2: 0.706 +- 0.011
# Mean train cv RMSE: 28339.441 +- 1061.498
# Mean train cv MAE: 13978.691 +- 282.920
#
#
# Mean val cv r^2: 0.713 +- 0.097
# Mean val cv RMSE: 27600.216 +- 9054.321
# Mean val cv MAE: 14241.824 +- 2395.260
# TransformedTargetRegressor(regressor=LinearRegression(),
#                            transformer=QuantileTransformer(n_quantiles=900,
#                                                            output_distribution='normal'))
