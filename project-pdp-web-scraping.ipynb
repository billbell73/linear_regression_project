# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time, os
import pickle

# %%
cars = {}

# %%
def scrape_initial_details(soup, car):
   advert_title = soup.find(attrs={"data-testid": "advert-title"})
   car['name'] = advert_title.text

   reg_age = advert_title.find_next_sibling('p').text
   car['year'] = reg_age.split()[0]

   miles_string = soup.find(id='ks-mileage').parent.find_next_sibling('span').text
   amount_only = miles_string.split()[0]
   amount_no_comma = amount_only.replace(',', '')
   car['mileage'] = int(amount_no_comma)

   price_string = soup.find(attrs={"data-testid": "advert-price"}).text
   price_digits_only = price_string.replace(',', '').replace('£', '')
   car['price'] = int(price_digits_only)

   car['advert_subtitle'] = soup.find(attrs={"data-testid": "advert-subtitle"}).text

   key_specs = []
   children = soup.find(attrs={"aria-label": "Key Specifications"}).findChildren("li")
   for child in children:
      key_specs.append(child.text.strip())

   car['body_type'] = key_specs[0]
   car['engine_size'] = float(key_specs[1].replace("L", ""))
   car['gearbox'] = key_specs[2]
   car['fuel_type'] = key_specs[3]
   car['doors'] = int(key_specs[4].split()[0])

   return car

# %%
def scrape_performance(soup, car):
   performance_expander = soup.find(attrs={"data-gui": "performance-expander"})
   lines = performance_expander.findChildren()[2].find_all('li')

   for line in lines:
      key = line.contents[0].text
      value = line.contents[1].text
      if "0-6" in key:
         car["0-6Xmph"] = float(value.split()[0])
      elif key == "Top Speed":
         car["top_speed"] = int(value.split()[0])
      elif key == "Cylinders":
         car["cylinders"] = int(value)
      elif key == "Engine power":
         car["power"] = int(value.split()[0])

   return car

# %%
def scrape_pdp(driver, url, car, car_id):
   driver.get(url)
   driver.maximize_window()
   time.sleep(0.6)
   soup = bs(driver.page_source)

   try:
      car = scrape_initial_details(soup, car)
   except Exception as e:
      print(f"Error scraping initial details. Car id: {car_id}")
      return car, (car_id, "intial_details", e)

   try:
      driver.execute_script("window.scrollTo(0, 1080)")
      driver.find_element_by_css_selector("*[data-testid='tech-spec-link']").click()
   except:
      iframe = driver.find_element_by_xpath("//iframe[@title='SP Consent Message']")
      driver.switch_to.frame(iframe)
      driver.find_element_by_css_selector("*[title='Accept All']").click()

      driver.switch_to.default_content()
      driver.execute_script("window.scrollTo(0, 1080)")
      driver.find_element_by_css_selector("*[data-testid='tech-spec-link']").click()

   time.sleep(0.5)
   soup_spec_modal = bs(driver.page_source)
   try:
      car = scrape_performance(soup_spec_modal, car)
   except Exception as e:
      print(f"Error scraping performance. Car id: {car_id}")
      return car, (car_id, "performance spec", e)

   return car, None

# %%
def scrape_paths(driver, car_ids, cars):
   incomplete_scrapes = []
   already_scraped = []

   for car_id in car_ids.keys():
      if car_id not in cars:
         car = {}
         car['id'] = car_id

         url = "https://www.autotrader.co.uk/car-details/" + car_id
         try:
            car, incomplete_scrape = scrape_pdp(driver, url, car, car_id)
            if incomplete_scrape:
               incomplete_scrapes.append(incomplete_scrape)
            else:
               cars[car_id] = car
         except Exception as e:
            incomplete_scrapes.append((car_id, "navigating", e))
      else:
         already_scraped.append(car_id)
           
   driver.quit()
   return cars, incomplete_scrapes, already_scraped

# %%
# Load data
with open('car_ids.pickle', 'rb') as handle:
#  '202107165112996': None,
#  '202110228787521': None,
#  '202107235349026': None,
#  '202107295588332': None,
#  '202110258876182': None,
#  '202110168547748': None,
#  '202110168547941': None,
#  '202103240531893': None,
#  '202108236550132': None,
#  '202109207582027': None,
#  '202109026896801': None,
#  '202106123761933': None,
#  '202107315675967': None,
#  '202110058150683': None,
#  '202110208696678': None,
#  '202109167425003': None,
#  '202110238810907': None,
#  '202110138443398': None,
#  '202110128390228': None,
#  '202107285550470': None,
#  '202110078219950': None,
#  '201904106817873': None,
#  '202109147362070': None,
#  '202109137316318': None,
#  '202106254223752': None,
#  '202109167431770': None,
#  '202109187518477': None,
#  '202110078244227': None,
#  '202110188608752': None,
#  '202109307951728': None,
#  '202109157408856': None,
#  '202110098310278': None,
#  '202110068171423': None,
#  '202107215278853': None,
#  '202109026901644': None,
#  '202109227676981': None,
#  '202110128401873': None,
#  '202107054662400': None,
#  '202108146241122': None,
#  '202109127288958': None,
#  '202106304445624': None,
#  '202104141354085': None,
#  '202005149321181': None,
#  '202110068199352': None,
#  '202109157387729': None,
#  '202110018009602': None,
#  '202108196406583': None,
#  '202108106072774': None,
#  '202109117257879': None,
#  '202107024546046': None,
#  '202106073575290': None,
#  '202110228778254': None,
#  '202108035779207': None,
#  '202110158528278': None,
#  '202110198644728': None,
#  '202110158508912': None,
#  '202110118347535': None,
#  '202109307960754': None,
#  '202108176342099': None,
#  '202108176326368': None,
#  '202109117251776': None,
#  '202110268893078': None,
#  '202110198665308': None,
#  '202110158523004': None,
#  '202109247763019': None,
#  '202109177481131': None,
#  '202109026910686': None,
#  '202108176319887': None,
#  '202108116098301': None,
#  '202107024547816': None,
#  '202106193996354': None,
#  '202105212920702': None,
#  '202103170261656': None,
#  '201702152347762': None,
#  '202110158509137': None,
#  '202110018016669': None,
#  '202110138434532': None,
#  '202109297937996': None,
#  '202110088256468': None,
#  '202110078222104': None,
#  '202109157399716': None,
#  '202110198644091': None,
#  '202108196425554': None,
#  '202110208712847': None,
#  '202108116114244': None,
#  '202109307953166': None,
#  '202109046977252': None,
#  '202108316827191': None,
#  '202103220448000': None,
#  '202109046978892': None,
#  '202110218740737': None,
#  '202106053502132': None,
#  '202109036946261': None,
#  '202110158509140': None,
#  '202110078229189': None,
#  ...}

# %%
len(car_ids)
# Out:
# 1742

# %%
chromedriver = "/Users/william.bell/opt/anaconda3/envs/metis/lib/python3.8/site-packages/chromedriver_binary/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
driver.implicitly_wait(3)

# %%
start = time.time()
cars, incomplete_scrapes, already_scraped = scrape_paths(driver, car_ids, cars)
end = time.time()
print(f"Time taken: {end - start}" )
# Out:
# Error scraping initial details. Car id: 202108065928307
# Error scraping initial details. Car id: 202108065928317
# Error scraping initial details. Car id: 202109026919221
# Error scraping initial details. Car id: 202107275528014
# Error scraping initial details. Car id: 202006109985445
# Error scraping initial details. Car id: 202105102436593
# Error scraping initial details. Car id: 202108276703564
# Error scraping initial details. Car id: 202108045833776
# Error scraping initial details. Car id: 202106103707766
# Error scraping initial details. Car id: 202110208690942
# Error scraping initial details. Car id: 202109267824672
# Error scraping initial details. Car id: 202110208695852
# Error scraping performance. Car id: 202110058154612
# Error scraping initial details. Car id: 202109077102396
# Error scraping initial details. Car id: 202109177481131
# Error scraping performance. Car id: 202109107220100
# Error scraping initial details. Car id: 202109147356226
# Error scraping initial details. Car id: 201905228233441
# Error scraping initial details. Car id: 202110018006674
# Error scraping initial details. Car id: 202109177471160
# Error scraping initial details. Car id: 202110158522367
# Error scraping initial details. Car id: 202108116098581
# Error scraping initial details. Car id: 202110058148613
# Error scraping initial details. Car id: 202110268889946
# Error scraping initial details. Car id: 202106083607490
# Error scraping performance. Car id: 202109227652675
# Error scraping initial details. Car id: 202110268891673
# Error scraping initial details. Car id: 202110158529022
# Error scraping initial details. Car id: 201703062968506
# Error scraping initial details. Car id: 201704033991344
# Error scraping initial details. Car id: 202110208681561
# Error scraping initial details. Car id: 202110228781686
# Error scraping initial details. Car id: 202109227668874
# Error scraping initial details. Car id: 202109287892525
# Error scraping initial details. Car id: 202108276699553
# Time taken: 5579.791272878647

# %%
incomplete_scrapes
# Out:
# [('202108065933948',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108065928307',
#   'intial_details',
#   ValueError("could not convert string to float: 'Manual'")),
#  ('202110218751352',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107155054619',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109247735912',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108065928317',
#   'intial_details',
#   ValueError("could not convert string to float: 'Manual'")),
#  ('202110258879062',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109067060278',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107074754868',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('201907220340973',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110058160035',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109026919221',
#   'intial_details',
#   ValueError("could not convert string to float: 'Manual'")),
#  ('202103170251830',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202010064664679',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107275528014',
#   'intial_details',
#   ValueError("could not convert string to float: 'Manual'")),
#  ('202109046993640',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110268901578',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202006109985445',
#   'intial_details',
#   ValueError("invalid literal for int() with base 10: 'Full'")),
#  ('202105102436593',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202108276703564',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202108045833776',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110188639220',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202106103707766',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110208690942',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202109267824672',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110238818261',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109197556324',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110208695852',
#   'intial_details',
#   ValueError("invalid literal for int() with base 10: 'Full'")),
#  ('202108276696505',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108196419394',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107145016704',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108286736131',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109217635770',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110208701830',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202106274303229',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109167444436',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('201706136402852',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109177482364',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202105202854855',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110058154612',
#   'performance spec',
#   AttributeError("'NoneType' object has no attribute 'findChildren'")),
#  ('202109307953954',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109277845055',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109077091891',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110128386264',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107305658808',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110168562511',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109016868863',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110268903405',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110268888764',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109127280893',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108136196693',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109297911802',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109167425079',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109147344299',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110238808261',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202106264292531',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109077102396',
#   'intial_details',
#   ValueError("invalid literal for int() with base 10: 'Full'")),
#  ('202109167428529',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110048103986',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109307951728',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202104141354085',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109177481131',
#   'intial_details',
#   ValueError("could not convert string to float: 'Unlisted'")),
#  ('202108116098301',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110198644091',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109107220100',
#   'performance spec',
#   AttributeError("'NoneType' object has no attribute 'findChildren'")),
#  ('202109147356226',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110068188637',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110048104105',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108015719493',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110168550908',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202103120053524',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('201905228233441',
#   'intial_details',
#   ValueError("could not convert string to float: 'Unlisted'")),
#  ('202103270658085',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109187506751',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109177482608',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110108336838',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110018006674',
#   'intial_details',
#   ValueError("could not convert string to float: 'Unlisted'")),
#  ('202110068196041',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109177471160',
#   'intial_details',
#   ValueError("could not convert string to float: 'Manual'")),
#  ('202110017995221',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110158522367',
#   'intial_details',
#   ValueError("could not convert string to float: 'Manual'")),
#  ('202107024551889',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202106183969482',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202104221662754',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110128421916',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110018008171',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110138428736',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109187518823',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108116098581',
#   'intial_details',
#   ValueError("could not convert string to float: 'Automatic'")),
#  ('202108045842523',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109147361289',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107225311986',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109177463440',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107265460725',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110058148613',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202102018574216',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110068184207',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110268889946',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110198662720',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202107155046212',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110118373163',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202106083607490', 'intial_details', IndexError('list index out of range')),
#  ('202011095955427',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110058129088',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110208683716',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109277834977',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110017990536',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109227652675',
#   'performance spec',
#   AttributeError("'NoneType' object has no attribute 'findChildren'")),
#  ('202110268891673',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110158529022',
#   'intial_details',
#   ValueError("could not convert string to float: 'Automatic'")),
#  ('202110048104025',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('201703062968506',
#   'intial_details',
#   ValueError("could not convert string to float: 'Unlisted'")),
#  ('201704033991344',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'parent'")),
#  ('202110208681561',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110228781686',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202005209439981',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110058138112',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110088270915',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109016874083',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110248832830',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109227668874',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202109237709753',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109277851699',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110168562315',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110158512732',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202005199406887',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('201911104223899',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110098310076',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202110158512739',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109287892525',
#   'intial_details',
#   AttributeError("'NoneType' object has no attribute 'text'")),
#  ('202110158510224',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202109137316071',
#   'navigating',
#   selenium.common.exceptions.NoSuchElementException('no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@title=\'SP Consent Message\']"}\n  (Session info: chrome=95.0.4638.54)',
#                                                     None,
#                                                     None)),
#  ('202108276699553', 'intial_details', IndexError('list index out of range'))]

# %%
len(incomplete_scrapes)
# Out:
# 133

# %%
len(already_scraped)
# Out:
# 3

# %%
len(cars)
# Out:
# 1609

# %%
cars

# %%
# Store data
with open('more_cars.pickle', 'wb') as handle:
   pickle.dump(cars, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Load data
with open('cars.pickle', 'rb') as handle:
   unserialized_data = pickle.load(handle)

unserialized_data
# Out:
# {'202109207563077': {'id': '202109207563077',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1821,
#   'price': 116900,
#   'advert_subtitle': '2dr PDK 3.0',
#   'body_type': 'Convertible',
#   'engine_size': 3.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.4,
#   'top_speed': 179,
#   'cylinders': 6,
#   'power': 380},
#  '202109227674550': {'id': '202109227674550',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 101000,
#   'price': 15995,
#   'advert_subtitle': '3.4 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202108136210396': {'id': '202108136210396',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 104825,
#   'price': 15995,
#   'advert_subtitle': 'CARRERA 4 TIP S 3.4 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202106043455421': {'id': '202106043455421',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 90650,
#   'price': 15995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202105082360787': {'id': '202105082360787',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 63800,
#   'price': 15995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202102239402326': {'id': '202102239402326',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 98000,
#   'price': 15995,
#   'advert_subtitle': '3.4 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110258855609': {'id': '202110258855609',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 57300,
#   'price': 16250,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202107215302341': {'id': '202107215302341',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 93555,
#   'price': 16495,
#   'advert_subtitle': '3.4 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110138442617': {'id': '202110138442617',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 118200,
#   'price': 16500,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202108306788653': {'id': '202108306788653',
#   'name': 'Porsche 911',
#   'year': '1998',
#   'mileage': 63000,
#   'price': 16750,
#   'advert_subtitle': '3.4 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110128395470': {'id': '202110128395470',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 104000,
#   'price': 16950,
#   'advert_subtitle': 'Carrera 2 3.6 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.0,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110188623506': {'id': '202110188623506',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 115000,
#   'price': 34995,
#   'advert_subtitle': '3.6 996 Turbo Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.8,
#   'top_speed': 185,
#   'cylinders': 6,
#   'power': 414},
#  '202108186392335': {'id': '202108186392335',
#   'name': 'Porsche 911',
#   'year': '2015',
#   'mileage': 44750,
#   'price': 63000,
#   'advert_subtitle': '3.4 CARRERA PDK 2d AUTO 350 BHP [SPORTS EXHAUST. PCM NAV. BOSE]',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.6,
#   'top_speed': 178,
#   'cylinders': 6,
#   'power': 345},
#  '202011256463759': {'id': '202011256463759',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 88540,
#   'price': 16950,
#   'advert_subtitle': '3.4 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202108276699111': {'id': '202108276699111',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 96000,
#   'price': 16995,
#   'advert_subtitle': '3.6 CARRERA 2 TIPTRONIC S 2d 316 BHP',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202106103693119': {'id': '202106103693119',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 85800,
#   'price': 16995,
#   'advert_subtitle': '3.6 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202105293249710': {'id': '202105293249710',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 84000,
#   'price': 16995,
#   'advert_subtitle': '3.4 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202105092394078': {'id': '202105092394078',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 62000,
#   'price': 17450,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202106294400981': {'id': '202106294400981',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 128050,
#   'price': 17500,
#   'advert_subtitle': '3.4 CARRERA 2d 300 BHP *FULL MAIN/SPECIALIST S/H+MANUAL**',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202105032133215': {'id': '202105032133215',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 103000,
#   'price': 17500,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202106304436928': {'id': '202106304436928',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 100000,
#   'price': 17750,
#   'advert_subtitle': '3.4 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109307982338': {'id': '202109307982338',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 106562,
#   'price': 17800,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110088266125': {'id': '202110088266125',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1749,
#   'price': 147900,
#   'advert_subtitle': '911 Targa 4S 3.0 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.4,
#   'top_speed': 189,
#   'cylinders': 6,
#   'power': 444},
#  '202108266653969': {'id': '202108266653969',
#   'name': 'Porsche 911',
#   'year': '2018',
#   'mileage': 8441,
#   'price': 98990,
#   'advert_subtitle': '2018 18 Porsche 911 3.0 Carrera GTS PDK Convertibl 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.8,
#   'top_speed': 191,
#   'cylinders': 6,
#   'power': 444},
#  '202109227667959': {'id': '202109227667959',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 211570,
#   'price': 8950,
#   'advert_subtitle': '3.4 996 Carrera 4 AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202108116107113': {'id': '202108116107113',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 89000,
#   'price': 10489,
#   'advert_subtitle': '3.6 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109157400086': {'id': '202109157400086',
#   'name': 'Porsche 911',
#   'year': '1998',
#   'mileage': 100500,
#   'price': 12500,
#   'advert_subtitle': '3.4 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110218731995': {'id': '202110218731995',
#   'name': 'Porsche 911',
#   'year': '1998',
#   'mileage': 104000,
#   'price': 12995,
#   'advert_subtitle': '3.4 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202105122515940': {'id': '202105122515940',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 180955,
#   'price': 12995,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109016858651': {'id': '202109016858651',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 101000,
#   'price': 13250,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110038063357': {'id': '202110038063357',
#   'name': 'Porsche 911',
#   'year': '1998',
#   'mileage': 120000,
#   'price': 13750,
#   'advert_subtitle': '3.4 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109177467070': {'id': '202109177467070',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 102000,
#   'price': 13999,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202107145034939': {'id': '202107145034939',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 92000,
#   'price': 14450,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110238822508': {'id': '202110238822508',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 115305,
#   'price': 14500,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110048110259': {'id': '202110048110259',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 4000,
#   'price': 117500,
#   'advert_subtitle': '3.0 CARRERA PDK 2d 380 BHP Very Low Mileage, Presented in Immaculate Condit',
#   'body_type': 'Convertible',
#   'engine_size': 3.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.4,
#   'top_speed': 181,
#   'cylinders': 6,
#   'power': 380},
#  '202110138439423': {'id': '202110138439423',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 126400,
#   'price': 14950,
#   'advert_subtitle': '3.4 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110018011992': {'id': '202110018011992',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 96000,
#   'price': 14995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202107195196068': {'id': '202107195196068',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 76000,
#   'price': 14995,
#   'advert_subtitle': '3.4 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202107195193335': {'id': '202107195193335',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 120000,
#   'price': 14999,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202008102312685': {'id': '202008102312685',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 85000,
#   'price': 14999,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109107237515': {'id': '202109107237515',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 109000,
#   'price': 15500,
#   'advert_subtitle': '3.4 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110158526487': {'id': '202110158526487',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 124500,
#   'price': 15950,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110128395467': {'id': '202110128395467',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 95000,
#   'price': 15950,
#   'advert_subtitle': 'Carrera 4 3.4 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202107305649118': {'id': '202107305649118',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 99000,
#   'price': 15990,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110098318816': {'id': '202110098318816',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 115000,
#   'price': 15995,
#   'advert_subtitle': '3.6 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202107084774284': {'id': '202107084774284',
#   'name': 'Porsche 911',
#   'year': '2016',
#   'mileage': 13818,
#   'price': 118900,
#   'advert_subtitle': 'S 2dr PDK 3.8',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.0,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 572},
#  '202107084769803': {'id': '202107084769803',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 66268,
#   'price': 17800,
#   'advert_subtitle': '3.4 996 Carrera 4 AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110208680471': {'id': '202110208680471',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 60700,
#   'price': 17950,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110168563609': {'id': '202110168563609',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 57889,
#   'price': 17950,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110128397095': {'id': '202110128397095',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 72000,
#   'price': 17990,
#   'advert_subtitle': '3.4 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110208715076': {'id': '202110208715076',
#   'name': 'Porsche 911',
#   'year': '1998',
#   'mileage': 71000,
#   'price': 17995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202107305638586': {'id': '202107305638586',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 76000,
#   'price': 17995,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202103300783414': {'id': '202103300783414',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 74362,
#   'price': 17995,
#   'advert_subtitle': '3.4 CARRERA CABRIOLET 2d 300 BHP **NEW EXHAUST+ 6 SPEED MANUAL**',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110208706643': {'id': '202110208706643',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 60160,
#   'price': 18450,
#   'advert_subtitle': '3.6 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202106193983444': {'id': '202106193983444',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 103000,
#   'price': 18495,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202107134985782': {'id': '202107134985782',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 91000,
#   'price': 18500,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109247772783': {'id': '202109247772783',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 97000,
#   'price': 18750,
#   'advert_subtitle': '3.6 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109187510335': {'id': '202109187510335',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 83000,
#   'price': 18750,
#   'advert_subtitle': '3.6 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110168560610': {'id': '202110168560610',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 85000,
#   'price': 18995,
#   'advert_subtitle': '3.6 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.0,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110068186371': {'id': '202110068186371',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 83000,
#   'price': 18995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109237711902': {'id': '202109237711902',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 71000,
#   'price': 18995,
#   'advert_subtitle': 'CARRERA 2 TIPTRONIC S - NEW ENGINE 3.6 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109207578053': {'id': '202109207578053',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 90381,
#   'price': 18995,
#   'advert_subtitle': '3.4 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109046982159': {'id': '202109046982159',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 74000,
#   'price': 18995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202105122516457': {'id': '202105122516457',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 47000,
#   'price': 26995,
#   'advert_subtitle': 'C4S 2dr Tiptronic S 3.6',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.9,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202108306805866': {'id': '202108306805866',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 76000,
#   'price': 18995,
#   'advert_subtitle': '3.6 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202107155056207': {'id': '202107155056207',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 60400,
#   'price': 18995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202106093655821': {'id': '202106093655821',
#   'name': 'Porsche 911',
#   'year': '1998',
#   'mileage': 97200,
#   'price': 18995,
#   'advert_subtitle': '3.4 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202107205253938': {'id': '202107205253938',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 74000,
#   'price': 19495,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109207598824': {'id': '202109207598824',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 120000,
#   'price': 19500,
#   'advert_subtitle': '3.6 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110258877646': {'id': '202110258877646',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 94000,
#   'price': 19750,
#   'advert_subtitle': '3.8 997 Carrera S Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.9,
#   'top_speed': 182,
#   'cylinders': 6,
#   'power': 350},
#  '202110208710306': {'id': '202110208710306',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 68150,
#   'price': 19900,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109036972273': {'id': '202109036972273',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 59706,
#   'price': 19950,
#   'advert_subtitle': '3.6 996 Targa Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202107124917738': {'id': '202107124917738',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 65000,
#   'price': 19950,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110068186483': {'id': '202110068186483',
#   'name': 'Porsche 911',
#   'year': '2015',
#   'mileage': 15400,
#   'price': 86950,
#   'advert_subtitle': '3.8 991 Carrera GTS PDK (s/s) 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.0,
#   'top_speed': 189,
#   'cylinders': 6,
#   'power': 430},
#  '202109277843992': {'id': '202109277843992',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 72000,
#   'price': 19990,
#   'advert_subtitle': '3.4 CARRERA TIPTRONIC S 2d 300 BHP FULL SERVICE HISTORY',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110268890792': {'id': '202110268890792',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 78000,
#   'price': 19995,
#   'advert_subtitle': '2dr Tiptronic S 3.6',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110258885773': {'id': '202110258885773',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 91000,
#   'price': 19995,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110018017524': {'id': '202110018017524',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 127000,
#   'price': 19995,
#   'advert_subtitle': '3.6 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109287903673': {'id': '202109287903673',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 80060,
#   'price': 19995,
#   'advert_subtitle': '3.6 996 Carrera 4 AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.0,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202109247764443': {'id': '202109247764443',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 64000,
#   'price': 19995,
#   'advert_subtitle': '3.4 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109167448106': {'id': '202109167448106',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 75517,
#   'price': 19995,
#   'advert_subtitle': '3.6 996 Carrera 4 Coupe 2dr Petrol Tiptronic S AWD (289 g/km, 315 bhp)',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109157413156': {'id': '202109157413156',
#   'name': 'Porsche 911',
#   'year': '2007',
#   'mileage': 149000,
#   'price': 19995,
#   'advert_subtitle': '3.6 997 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 325},
#  '202108306787266': {'id': '202108306787266',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 65214,
#   'price': 19995,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202108186373605': {'id': '202108186373605',
#   'name': 'Porsche 911',
#   'year': '1999',
#   'mileage': 71600,
#   'price': 19995,
#   'advert_subtitle': '3.4 996 Carrera 4 AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202110228774671': {'id': '202110228774671',
#   'name': 'Porsche 911',
#   'year': '2013',
#   'mileage': 62000,
#   'price': 56990,
#   'advert_subtitle': '3.8 CARRERA 4S 2d 400 BHP PASM 20MM LOWERED SPORT SUSPENSION',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.5,
#   'top_speed': 185,
#   'cylinders': 6,
#   'power': 395},
#  '202107205248829': {'id': '202107205248829',
#   'name': 'Porsche 911',
#   'year': '2000',
#   'mileage': 59000,
#   'price': 19995,
#   'advert_subtitle': '3.4 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202106123780358': {'id': '202106123780358',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 42100,
#   'price': 19995,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202008042067724': {'id': '202008042067724',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 131193,
#   'price': 19995,
#   'advert_subtitle': '3.6 996 Carrera 4 Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202107084773198': {'id': '202107084773198',
#   'name': 'Porsche 911',
#   'year': '2001',
#   'mileage': 89990,
#   'price': 19999,
#   'advert_subtitle': '3.4 996 Carrera 4 Cabriolet AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.4,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 175,
#   'cylinders': 6,
#   'power': 300},
#  '202109217642376': {'id': '202109217642376',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 85750,
#   'price': 20500,
#   'advert_subtitle': '3.6 CARRERA 4 TIPTRONIC S 2d 316 BHP FREE NATIONWIDE DELIVERY!',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110038078344': {'id': '202110038078344',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 100000,
#   'price': 20750,
#   'advert_subtitle': '3.6 997 Carrera Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 325},
#  '202109267821404': {'id': '202109267821404',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 106650,
#   'price': 20950,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110088254636': {'id': '202110088254636',
#   'name': 'Porsche 911',
#   'year': '2006',
#   'mileage': 138000,
#   'price': 20990,
#   'advert_subtitle': '3.6 997 Carrera 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.0,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 325},
#  '202110218741169': {'id': '202110218741169',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 59953,
#   'price': 20995,
#   'advert_subtitle': '3.6 996 Targa Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110078225059': {'id': '202110078225059',
#   'name': 'Porsche 911',
#   'year': '2017',
#   'mileage': 17000,
#   'price': 71995,
#   'advert_subtitle': '3.0T 991 Carrera PDK (s/s) 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.2,
#   'top_speed': 182,
#   'cylinders': 6,
#   'power': 365},
#  '202110138462829': {'id': '202110138462829',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 59000,
#   'price': 20995,
#   'advert_subtitle': '3.6 997 Carrera 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.0,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 325},
#  '202110068187230': {'id': '202110068187230',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 77000,
#   'price': 20995,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109297918011': {'id': '202109297918011',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 69800,
#   'price': 20995,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202106244178175': {'id': '202106244178175',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 72300,
#   'price': 20995,
#   'advert_subtitle': '3.6 996 Targa Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202107235373158': {'id': '202107235373158',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 86251,
#   'price': 20999,
#   'advert_subtitle': '3.6 CARRERA 2 TIPTRONIC S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202108035795307': {'id': '202108035795307',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 122109,
#   'price': 21044,
#   'advert_subtitle': '3.6 CARRERA 4 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110018006669': {'id': '202110018006669',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 77407,
#   'price': 21495,
#   'advert_subtitle': '3.6 CARRERA 2 TIPTRONIC S 2d 316 BHP HARD TOP',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202108086000934': {'id': '202108086000934',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 138800,
#   'price': 21500,
#   'advert_subtitle': '3.8 997 Carrera S Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.4,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 350},
#  '202107014490515': {'id': '202107014490515',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 91500,
#   'price': 21750,
#   'advert_subtitle': '3.6 996 Carrera 4S Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.9,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202008062162109': {'id': '202008062162109',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 84000,
#   'price': 21900,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202108286743462': {'id': '202108286743462',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 72000,
#   'price': 21990,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110048114842': {'id': '202110048114842',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 67470,
#   'price': 21995,
#   'advert_subtitle': '3.6 996 Targa 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202109277845944': {'id': '202109277845944',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 90000,
#   'price': 21995,
#   'advert_subtitle': '3.6 996 Targa Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202106274323254': {'id': '202106274323254',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 45600,
#   'price': 21995,
#   'advert_subtitle': '3.6 996 Carrera 2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.0,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110108327835': {'id': '202110108327835',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 100000,
#   'price': 22000,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202012086910702': {'id': '202012086910702',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 120000,
#   'price': 22000,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202108055887767': {'id': '202108055887767',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 50743,
#   'price': 22495,
#   'advert_subtitle': '3.6 996 Carrera 4 Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110138451267': {'id': '202110138451267',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 99400,
#   'price': 22500,
#   'advert_subtitle': '3.8 997 Carrera S Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.3,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 350},
#  '202110108339041': {'id': '202110108339041',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 81400,
#   'price': 22500,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110088266799': {'id': '202110088266799',
#   'name': 'Porsche 911',
#   'year': '2006',
#   'mileage': 104000,
#   'price': 22500,
#   'advert_subtitle': '3.8 997 Carrera S Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.3,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 350},
#  '202110038080535': {'id': '202110038080535',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 45000,
#   'price': 22500,
#   'advert_subtitle': '3.6 996 Carrera 2 Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109277859066': {'id': '202109277859066',
#   'name': 'Porsche 911',
#   'year': '2006',
#   'mileage': 133000,
#   'price': 22795,
#   'advert_subtitle': '3.8 997 Carrera 4S Cabriolet Tiptronic S AWD 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.4,
#   'top_speed': 179,
#   'cylinders': 6,
#   'power': 350},
#  '202110198643616': {'id': '202110198643616',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 86000,
#   'price': 22950,
#   'advert_subtitle': '3.6 997 Carrera Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 325},
#  '202109157402905': {'id': '202109157402905',
#   'name': 'Porsche 911',
#   'year': '2008',
#   'mileage': 153572,
#   'price': 22950,
#   'advert_subtitle': '3.8 997 Carrera S Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.3,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 350},
#  '202109237711884': {'id': '202109237711884',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 82776,
#   'price': 22990,
#   'advert_subtitle': '3.6 CARRERA 2 2d 316 BHP * PART EXCHANGE WELCOMED *',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202110228789995': {'id': '202110228789995',
#   'name': 'Porsche 911',
#   'year': '2005',
#   'mileage': 96000,
#   'price': 22995,
#   'advert_subtitle': '3.6 997 Carrera Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 325},
#  '202110078212904': {'id': '202110078212904',
#   'name': 'Porsche 911',
#   'year': '2004',
#   'mileage': 93000,
#   'price': 22995,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109026902983': {'id': '202109026902983',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 42000,
#   'price': 22995,
#   'advert_subtitle': '3.6 996 Targa 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.2,
#   'top_speed': 177,
#   'cylinders': 6,
#   'power': 315},
#  '202109016862202': {'id': '202109016862202',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 102000,
#   'price': 22995,
#   'advert_subtitle': '3.6 996 Targa Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109247739550': {'id': '202109247739550',
#   'name': 'Porsche 911',
#   'year': '2002',
#   'mileage': 48900,
#   'price': 23495,
#   'advert_subtitle': '3.6 996 Carrera 2 Tiptronic S 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.5,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109217642375': {'id': '202109217642375',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 91750,
#   'price': 23495,
#   'advert_subtitle': '3.6 CARRERA 4S TIPTRONIC S 2d 316 BHP RARE INVESTMENT OPPORTUNITY!!',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202110078226912': {'id': '202110078226912',
#   'name': 'Porsche 911',
#   'year': '2003',
#   'mileage': 82350,
#   'price': 23500,
#   'advert_subtitle': '3.6 996 Carrera 4S Tiptronic S AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.6,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 315},
#  '202109267817660': {'id': '202109267817660',
#   'name': 'Porsche 911',
#   'year': '2006',
#   'mileage': 60000,
#   'price': 23500,
#   'advert_subtitle': '3.6 997 Carrera Cabriolet Tiptronic S 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.6,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.7,
#   'top_speed': 174,
#   'cylinders': 6,
#   'power': 325},
#  '202110118376069': {'id': '202110118376069',
#   'name': 'Porsche 911',
#   'year': '2001',
# ...
#   'mileage': 71,
#   'price': 315000,
#   'advert_subtitle': '991 SPEEDSTER SPECIAL EDITIONS 2dr 4.0',
#   'body_type': 'Convertible',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.0,
#   'top_speed': 192,
#   'cylinders': 6,
#   'power': 510},
#  '202107305648236': {'id': '202107305648236',
#   'name': 'Porsche 911',
#   'year': '1995',
#   'mileage': 58225,
#   'price': 299995,
#   'advert_subtitle': '3.7 993 Carrera RS Limited Edition 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.7,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   'cylinders': 6,
#   'power': 300},
#  '202109137303742': {'id': '202109137303742',
#   'name': 'Porsche 911',
#   'year': '1996',
#   'mileage': 31700,
#   'price': 295000,
#   'advert_subtitle': '3.6 993 Turbo AWD 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 5.3,
#   'top_speed': 171,
#   'cylinders': 6,
#   'power': 408},
#  '202109147348637': {'id': '202109147348637',
#   'name': 'Porsche 911',
#   'year': '2019',
#   'mileage': 3970,
#   'price': 284950,
#   'advert_subtitle': '4.0 Speedster 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.0,
#   'top_speed': 192,
#   'cylinders': 6,
#   'power': 510},
#  '202105022110595': {'id': '202105022110595',
#   'name': 'Porsche 911',
#   'year': '2018',
#   'mileage': 15000,
#   'price': 279989,
#   'advert_subtitle': '3.8T 991 GT2 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.8,
#   'top_speed': 211,
#   'cylinders': 6,
#   'power': 690},
#  '202110068199110': {'id': '202110068199110',
#   'name': 'Porsche 911',
#   'year': '2011',
#   'mileage': 21705,
#   'price': 275000,
#   'advert_subtitle': '3.8 997 Speedster Cabriolet PDK 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.9,
#   'top_speed': 178,
#   'cylinders': 6,
#   'power': 408},
#  '202110218738223': {'id': '202110218738223',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 500,
#   'price': 260199,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202109287881000': {'id': '202109287881000',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 862,
#   'price': 253990,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202109277849732': {'id': '202109277849732',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 10,
#   'price': 249995,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202110258882761': {'id': '202110258882761',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 700,
#   'price': 249950,
#   'advert_subtitle': '4.0 992 GT3 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.9,
#   'top_speed': 199,
#   'cylinders': 6,
#   'power': 510},
#  '202108266672927': {'id': '202108266672927',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 997,
#   'price': 249950,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202109287872850': {'id': '202109287872850',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1101,
#   'price': 248950,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202108286738517': {'id': '202108286738517',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1170,
#   'price': 244995,
#   'advert_subtitle': 'GT3 4.0 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202108266675767': {'id': '202108266675767',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 500,
#   'price': 244975,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202109277849034': {'id': '202109277849034',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 283,
#   'price': 244950,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202109287891416': {'id': '202109287891416',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 3000,
#   'price': 240000,
#   'advert_subtitle': 'GT3 4.0 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.9,
#   'top_speed': 199,
#   'cylinders': 6,
#   'power': 510},
#  '202110128423297': {'id': '202110128423297',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1043,
#   'price': 239995,
#   'advert_subtitle': '4.0 992 GT3 PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.4,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 510},
#  '202109307974511': {'id': '202109307974511',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 650,
#   'price': 239995,
#   'advert_subtitle': '4.0 992 GT3 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.9,
#   'top_speed': 199,
#   'cylinders': 6,
#   'power': 510},
#  '202110218728236': {'id': '202110218728236',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 350,
#   'price': 234995,
#   'advert_subtitle': '4.0 992 GT3 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.9,
#   'top_speed': 199,
#   'cylinders': 6,
#   'power': 510},
#  '202110058137659': {'id': '202110058137659',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1796,
#   'price': 229950,
#   'advert_subtitle': '4.0 992 GT3 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.9,
#   'top_speed': 199,
#   'cylinders': 6,
#   'power': 510},
#  '202110138445625': {'id': '202110138445625',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 871,
#   'price': 225000,
#   'advert_subtitle': '992 TURBO COUPE S 2dr PDK 3.8',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.7,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202110058125683': {'id': '202110058125683',
#   'name': 'Porsche 911',
#   'year': '2020',
#   'mileage': 1995,
#   'price': 225000,
#   'advert_subtitle': 'GT3 RS PDK 4.0 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202110148472122': {'id': '202110148472122',
#   'name': 'Porsche 911',
#   'year': '2020',
#   'mileage': 2227,
#   'price': 224995,
#   'advert_subtitle': '3.8T 992 Turbo S Convertible 2dr Petrol PDK 4WD (s/s) (650 ps)',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.8,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202110078227457': {'id': '202110078227457',
#   'name': 'Porsche 911',
#   'year': '2019',
#   'mileage': 1243,
#   'price': 222500,
#   'advert_subtitle': '4.0 991 GT3 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202110218747099': {'id': '202110218747099',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 500,
#   'price': 219950,
#   'advert_subtitle': '3.8T 992 Turbo S PDK 4WD (s/s) 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.7,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202110098293474': {'id': '202110098293474',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 2203,
#   'price': 218950,
#   'advert_subtitle': 'TURBO S PDK 3.8 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.8,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202110128407614': {'id': '202110128407614',
#   'name': 'Porsche 911',
#   'year': '2019',
#   'mileage': 4940,
#   'price': 215950,
#   'advert_subtitle': '4.0 991 GT3 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202110138446054': {'id': '202110138446054',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 100,
#   'price': 215000,
#   'advert_subtitle': '3.8T 992 Turbo S PDK 4WD (s/s) 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.8,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202109307971840': {'id': '202109307971840',
#   'name': 'Porsche 911',
#   'year': '2019',
#   'mileage': 3750,
#   'price': 214995,
#   'advert_subtitle': '4.0 991 GT3 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202109157382271': {'id': '202109157382271',
#   'name': 'Porsche 911',
#   'year': '2018',
#   'mileage': 5100,
#   'price': 210000,
#   'advert_subtitle': '911 991 GT3 Touring 4.0 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.9,
#   'top_speed': 198,
#   'cylinders': 6,
#   'power': 500},
#  '202110128400755': {'id': '202110128400755',
#   'name': 'Porsche 911',
#   'year': '2018',
#   'mileage': 6652,
#   'price': 209995,
#   'advert_subtitle': '4.0 991 GT3 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202109297945714': {'id': '202109297945714',
#   'name': 'Porsche 911',
#   'year': '2019',
#   'mileage': 5200,
#   'price': 209995,
#   'advert_subtitle': 'GT3 RS. FRONT AXLE LIFT. BOSE. SPORTS BUCKETS. LEATHER & ALCANTARA INTERIOR 4.0 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202107285548145': {'id': '202107285548145',
#   'name': 'Porsche 911',
#   'year': '2019',
#   'mileage': 3981,
#   'price': 209950,
#   'advert_subtitle': '4.0 991 GT3 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  '202106294405978': {'id': '202106294405978',
#   'name': 'Porsche 911',
#   'year': '2021',
#   'mileage': 1600,
#   'price': 209900,
#   'advert_subtitle': '3.8T 992 Turbo S PDK 4WD (s/s) 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.7,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202110048106319': {'id': '202110048106319',
#   'name': 'Porsche 911',
#   'year': '2020',
#   'mileage': 7811,
#   'price': 204990,
#   'advert_subtitle': '3.8T 992 Turbo S PDK 4WD (s/s) 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.8,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202109247735566': {'id': '202109247735566',
#   'name': 'Porsche 911',
#   'year': '2020',
#   'mileage': 2156,
#   'price': 204000,
#   'advert_subtitle': '992 TURBO COUPE S 2dr PDK 3.8',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.7,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202110268897800': {'id': '202110268897800',
#   'name': 'Porsche 911',
#   'year': '1989',
#   'mileage': 19165,
#   'price': 199995,
#   'advert_subtitle': '3.3 Classic Turbo Cabriolet 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.3,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   'cylinders': 6,
#   'power': 300},
#  '202109097185261': {'id': '202109097185261',
#   'name': 'Porsche 911',
#   'year': '1989',
#   'mileage': 9850,
#   'price': 199995,
#   'advert_subtitle': '3.3 Classic Turbo 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.3,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   'cylinders': 6,
#   'power': 300},
#  '202104221682265': {'id': '202104221682265',
#   'name': 'Porsche 911',
#   'year': '1986',
#   'mileage': 22782,
#   'price': 199995,
#   'advert_subtitle': 'TURBO. SE. 930. FACTORY BUILT FLATNOSE. 1 OF 50 RHD CARS. GENUINE C16 CAR 3.3 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.3,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   'cylinders': 6,
#   'power': 300},
#  '202103160219374': {'id': '202103160219374',
#   'name': 'Porsche 911',
#   'year': '1973',
#   'mileage': 108832,
#   'price': 199995,
#   'advert_subtitle': '3.2 Classic Carrera 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.2,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   'cylinders': 6,
#   'power': 231},
#  '202004088897250': {'id': '202004088897250',
#   'name': 'Porsche 911',
#   'year': '2008',
#   'mileage': 14000,
#   'price': 199995,
#   'advert_subtitle': '3.6 997 GT2 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.6,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.6,
#   'top_speed': 204,
#   'cylinders': 6,
#   'power': 530},
#  '202105062298775': {'id': '202105062298775',
#   'name': 'Porsche 911',
#   'year': '2020',
#   'mileage': 10000,
#   'price': 199990,
#   'advert_subtitle': '3.8T 992 Turbo S PDK 4WD (s/s) 2dr',
#   'body_type': 'Convertible',
#   'engine_size': 3.8,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 2.8,
#   'top_speed': 205,
#   'cylinders': 6,
#   'power': 641},
#  '202109107206993': {'id': '202109107206993',
#   'name': 'Porsche 911',
#   'year': '1990',
#   'mileage': 14000,
#   'price': 199980,
#   'advert_subtitle': '3.2 Classic Carrera Speedster 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.2,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   'cylinders': 6,
#   'power': 231},
#  '202110148490078': {'id': '202110148490078',
#   'name': 'Porsche 911',
#   'year': '2010',
#   'mileage': 500,
#   'price': 199975,
#   'advert_subtitle': 'GT3 RS 3.8 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 3.8,
#   'gearbox': 'Manual',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 4.0,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 444},
#  '202110258861790': {'id': '202110258861790',
#   'name': 'Porsche 911',
#   'year': '2018',
#   'mileage': 5300,
#   'price': 199950,
#   'advert_subtitle': '4.0 991 GT3 RS PDK 2dr',
#   'body_type': 'Coupe',
#   'engine_size': 4.0,
#   'gearbox': 'Automatic',
#   'fuel_type': 'Petrol',
#   'doors': 2,
#   '0-6Xmph': 3.2,
#   'top_speed': 193,
#   'cylinders': 6,
#   'power': 520},
#  ...}
